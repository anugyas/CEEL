# %%
import numpy as np
import pylab as p
import matplotlib.pyplot as plt
import math
import pandas
from google.colab import drive
import os
import json
from random import *
from sympy import *
import torch
import jax
import jax.numpy as jnp
from jax import grad, config
jax.config.update("jax_debug_nans", True)

# %%
path_to_sepsis_with_lab_values_csv = "/content/No_NaN_Values_Latest.csv"

sepsis_with_lab_values_df = pandas.read_csv(path_to_sepsis_with_lab_values_csv)

sepsis_with_lab_values_df.describe()

sepsis_with_lab_values_df.head()

count  = 0

list_of_patient_values = []

for _, row in sepsis_with_lab_values_df.iterrows():
  count = count + 1
  patient_values = {}
  patient_values["respiration"] = ([],[],[])
  patient_values["coagulation"] = ([],[])
  patient_values["liver"] = ([],[])
  patient_values["cardiovascular"] = ([],[],[],[],[],[])
  patient_values["cns"] = ([],[])
  patient_values["renal"] = ([],[],[])
  patient_values["sofa_score"] = None
  patient_values["respiration"][0].append(row["pao2fio2ratio_novent"])
  patient_values["respiration"][1].append(row["pao2fio2ratio_vent"])
  patient_values["respiration"][2].append(row["respiration"])
  patient_values["coagulation"][0].append(row["platelet_min"])
  patient_values["coagulation"][1].append(row["coagulation"])
  patient_values["liver"][0].append(row["bilirubin_max"])
  patient_values["liver"][1].append(row["liver"])
  patient_values["cardiovascular"][0].append(row["rate_dopamine"])
  patient_values["cardiovascular"][1].append(row["rate_epinephrine"])
  patient_values["cardiovascular"][2].append(row["rate_norepinephrine"])
  patient_values["cardiovascular"][3].append(row["rate_dobutamine"])
  patient_values["cardiovascular"][4].append(row["meanbp_min"])
  patient_values["cardiovascular"][5].append(row["cardiovascular"])
  patient_values["cns"][0].append(row["gcs_min"])
  patient_values["cns"][1].append(row["cns"])
  patient_values["renal"][0].append(row["creatinine_max"])
  patient_values["renal"][1].append(row["uo_24hr"])
  patient_values["renal"][2].append(row["renal"])
  patient_values["sofa_score"] = row["sofa_score"]
  list_of_patient_values.append(patient_values)

print(count, " values loaded!")

# sepsis_with_lab_values_df.hist(column=["pao2fio2ratio_vent","respiration"])
# sepsis_with_lab_values_df.hist(column=["pao2fio2ratio_novent","respiration"])
# sepsis_with_lab_values_df.hist(column=["platelet_min","coagulation"])
# sepsis_with_lab_values_df.hist(column=["bilirubin_max","liver"])
# sepsis_with_lab_values_df.hist(column=["rate_dopamine","cardiovascular"])
# sepsis_with_lab_values_df.hist(column=["rate_epinephrine","cardiovascular"])
# sepsis_with_lab_values_df.hist(column=["rate_norepinephrine","cardiovascular"])
# sepsis_with_lab_values_df.hist(column=["rate_dobutamine","cardiovascular"])
# sepsis_with_lab_values_df.hist(column=["meanbp_min","cardiovascular"])
# sepsis_with_lab_values_df.hist(column=["gcs_min","cns"])
# sepsis_with_lab_values_df.hist(column=["creatinine_max","renal"])
# sepsis_with_lab_values_df.hist(column=["uo_24hr","renal"])
# sepsis_with_lab_values_df.hist(column="death_flag")

def h_respiration_discrete_original(pao2_fio2_ratio_novent, pao2_fio2_ratio_vent):
    if pao2_fio2_ratio_novent is None and pao2_fio2_ratio_vent is None:
        respiration_sofa is None
    elif pao2_fio2_ratio_vent < 100:
        respiration_sofa = 4
    elif pao2_fio2_ratio_vent < 200:
        respiration_sofa = 3
    elif pao2_fio2_ratio_novent < 300:
        respiration_sofa = 2
    elif pao2_fio2_ratio_vent < 300:
        respiration_sofa = 2
    elif pao2_fio2_ratio_novent < 400:
        respiration_sofa = 1
    elif pao2_fio2_ratio_vent < 400:
        respiration_sofa = 1
    else:
        respiration_sofa = 0
    return respiration_sofa


def h_respiration_vent_cont(pao2_fio2_ratio_vent, beta=10):
  respiration_sofa_vent_cont = 1/(1+jnp.exp(beta*((pao2_fio2_ratio_vent/100)-1))) + 1/(1+jnp.exp(beta*((pao2_fio2_ratio_vent/100)-2))) +1/(1+jnp.exp(beta*((pao2_fio2_ratio_vent/100)-3))) + 1/(1+jnp.exp(beta*((pao2_fio2_ratio_vent/100)-4)))
  return respiration_sofa_vent_cont


def h_respiration_novent_cont(pao2_fio2_ratio_novent, beta=10):
  respiration_sofa_novent_cont = 1/(1+jnp.exp(beta*((pao2_fio2_ratio_novent/100)-3))) + 1/(1+jnp.exp(beta*((pao2_fio2_ratio_novent/100)- 4)))
  return respiration_sofa_novent_cont


def h_respiration_cont(pao2_fio2_ratio_novent, pao2_fio2_ratio_vent, alpha=5):
  respiration_sofa_vent_cont = h_respiration_vent_cont(pao2_fio2_ratio_vent)
  respiration_sofa_novent_cont = h_respiration_novent_cont(pao2_fio2_ratio_novent)
  respiration_sofa_cont = (respiration_sofa_vent_cont*jnp.exp(alpha*respiration_sofa_vent_cont) + respiration_sofa_novent_cont*jnp.exp(alpha*respiration_sofa_novent_cont))/(jnp.exp(alpha*respiration_sofa_vent_cont) + jnp.exp(alpha*respiration_sofa_novent_cont))
  return respiration_sofa_cont


def h_renal_discrete_original(creatinine_max, uo_24hr):
  if creatinine_max >= 5:
    renal_sofa = 4
  elif uo_24hr < 200:
    renal_sofa = 4
  elif creatinine_max >= 3.5:
    renal_sofa = 3
  elif uo_24hr < 500:
    renal_sofa = 3
  elif creatinine_max >= 2:
    renal_sofa = 2
  elif creatinine_max >= 1.2:
    renal_sofa = 1
  elif creatinine_max is None and uo_24hr is None:
    renal_sofa = None
  else:
    renal_sofa = 0
  return renal_sofa


def h_renal_cont_creatinine(creatinine_max, beta=2):
  renal_sofa_cont_creatinine = 1/(1+jnp.exp(beta*((-1)*(creatinine_max - 1.2)))) + 1/(1+jnp.exp(beta*((-1)*(creatinine_max - 2)))) + 1/(1+jnp.exp(beta*((-1)*(creatinine_max - 3.5)))) + 1/(1+jnp.exp(beta*((-1)*(creatinine_max - 5)))) 
  return renal_sofa_cont_creatinine


def h_renal_cont_uo_24hr(uo_24hr,beta=25):
  renal_sofa_cont_uo_24hr = 1/(1+jnp.exp(beta*(((uo_24hr/1000) - 0.2)))) + 3/(1+jnp.exp(beta*(((uo_24hr/1000) - 0.5)))) 
  return renal_sofa_cont_uo_24hr
  

def h_renal_cont(creatinine_max, uo_24hr, alpha=5):
  creatinine_max_op = h_renal_cont_creatinine(creatinine_max)
  uo_24_hr_op = h_renal_cont_uo_24hr(uo_24hr)
  renal_sofa = (creatinine_max_op*jnp.exp(alpha*creatinine_max_op) + uo_24_hr_op*jnp.exp(alpha*uo_24_hr_op))/(jnp.exp(alpha*creatinine_max_op) + jnp.exp(alpha*uo_24_hr_op))
  return renal_sofa


def h_cardiovascular_discrete_original(rate_dopamine, rate_epinephrine, rate_norepinephrine, rate_dobutamine, meanbp_min):
  if rate_dopamine is None and rate_epinephrine is None and rate_norepinephrine is None and rate_dobutamine is None and rate_dopamine is None and meanbp_min is None:
    cardiovascular_sofa = None
  else:
    if rate_dopamine > 15:
      cardiovascular_sofa = 4
    elif rate_epinephrine > 0.1:
      cardiovascular_sofa = 4
    elif rate_norepinephrine > 0.1:
      cardiovascular_sofa = 4
    elif rate_dopamine > 5:
      cardiovascular_sofa = 3
    elif rate_epinephrine > 0:
      cardiovascular_sofa = 3
    elif rate_norepinephrine > 0:
      cardiovascular_sofa = 3
    elif rate_dopamine > 0:
      cardiovascular_sofa = 2
    elif rate_dobutamine > 0:
      cardiovascular_sofa = 2
    elif meanbp_min < 70:
      cardiovascular_sofa = 1
    else:
      cardiovascular_sofa = 0
  return cardiovascular_sofa


def h_cardiovascular_dopamine_cont(rate_dopamine, beta=10):
  cardiovascular_dopamine_cont_sofa = 1/(1+jnp.exp(beta*((-1)*(rate_dopamine/10 - 1.5)))) + 1/(1+jnp.exp(beta*((-1)*(rate_dopamine/10 - 5)))) + 2/(1+jnp.exp(beta*((-1)*(rate_dopamine/10))))
  return cardiovascular_dopamine_cont_sofa


def h_cardiovascular_epinephrine_cont(rate_epinephrine, beta=10):
  cardiovascular_epinephrine_cont_sofa = 1/(1+jnp.exp(beta*((-1)*((rate_epinephrine) - 0.1)))) + 3/(1+jnp.exp(beta*((-1)*((rate_epinephrine)))))
  return cardiovascular_epinephrine_cont_sofa


def h_cardiovascular_norepinephrine_cont(rate_norepinephrine, beta=10):
  cardiovascular_norepinephrine_cont_sofa = 1/(1+jnp.exp(beta*((-1)*((rate_norepinephrine) - 0.1)))) + 3/(1+jnp.exp(beta*((-1)*((rate_norepinephrine)))))
  return cardiovascular_norepinephrine_cont_sofa


def h_cardiovascular_dobutamine_cont(rate_dobutamine, beta=10):
  cardiovascular_dobutamine_cont = 2/(1+jnp.exp(beta*((-1)*(rate_dobutamine))))
  return cardiovascular_dobutamine_cont

def h_cardiovascular_meanbp_min_cont(meanbp_min, beta=20):
  cardiovascular_meanbp_min_cont = 1/(1+jnp.exp(beta*((meanbp_min/100) - 0.7)))
  return cardiovascular_meanbp_min_cont


def h_cardiovascular_cont(rate_dopamine, rate_epinephrine, rate_norepinephrine, rate_dobutamine, meanbp_min, alpha=20):
  dopamine_score = h_cardiovascular_dopamine_cont(rate_dopamine)
  epinephrine_score = h_cardiovascular_epinephrine_cont(rate_epinephrine)
  norepinephrine_score = h_cardiovascular_norepinephrine_cont(rate_norepinephrine)
  dobutamine_score = h_cardiovascular_dobutamine_cont(rate_dobutamine)
  meanbp_min_score = h_cardiovascular_meanbp_min_cont(meanbp_min)
  cardiovascular_sofa_cont = (dopamine_score*jnp.exp(alpha*dopamine_score) + epinephrine_score*jnp.exp(alpha*epinephrine_score) + norepinephrine_score*jnp.exp(alpha*norepinephrine_score) + dobutamine_score*jnp.exp(alpha*dobutamine_score) + meanbp_min_score*jnp.exp(alpha*meanbp_min_score))/(jnp.exp(alpha*dopamine_score) + jnp.exp(alpha*dobutamine_score) + jnp.exp(alpha*epinephrine_score) + jnp.exp(alpha*norepinephrine_score) + jnp.exp(alpha*meanbp_min_score))
  return cardiovascular_sofa_cont

def h_cns_discrete_original(gcs_min):
  if gcs_min is None:
    cns_sofa = None
  elif gcs_min < 6:
    cns_sofa = 4
  elif gcs_min <= 9:
    cns_sofa = 3
  elif gcs_min <= 12:
    cns_sofa = 2
  elif gcs_min < 14:
    cns_sofa = 1
  else:
    cns_sofa = 0
  return cns_sofa

def h_cns_cont(gcs_min, beta=2):
  cns_sofa_cont = 1/(1+jnp.exp(beta*(gcs_min/10 - 0.6))) + 1/(1+jnp.exp(beta*(gcs_min/10 - 0.9))) + 1/(1+jnp.exp(beta*(gcs_min/10 - 1.2))) + 1/(1+jnp.exp(beta*(gcs_min/10 - 1.4)))
  return cns_sofa_cont

def h_coagulation_discrete_original(platelet_min):
  if platelet_min < 20:
    coagulation_sofa = 4
  elif platelet_min < 50:
    coagulation_sofa = 3
  elif platelet_min < 100:
    coagulation_sofa = 2
  elif platelet_min < 150:
    coagulation_sofa = 1
  elif platelet_min is None:
    coagulation_sofa = None
  else:
    coagulation_sofa = 0
  return coagulation_sofa

def h_coagulation_cont(platelet_min, beta=15):
  coagulation_sofa_cont = 1/(1+jnp.exp(beta*((platelet_min/100)-0.2))) + 1/(1+jnp.exp(beta*((platelet_min/100)-0.5))) + 1/(1+jnp.exp(beta*((platelet_min/100)-1))) + 1/(1+jnp.exp(beta*((platelet_min/100)-1.5)))
  return coagulation_sofa_cont

def h_liver_discrete_original(bilirubin_max):
  if bilirubin_max is None:
    liver_sofa = None
  elif bilirubin_max >= 12.0:
    liver_sofa = 4
  elif bilirubin_max >= 6.0:
    liver_sofa = 3
  elif bilirubin_max >= 2.0:
    liver_sofa = 2
  elif bilirubin_max >= 1.2:
    liver_sofa = 1
  else:
    liver_sofa = 0
  return liver_sofa

def h_liver_cont(bilirubin_max , beta=2):
  liver_sofa_cont = 1/(1+jnp.exp(beta*(-(bilirubin_max/10 - 1.2)))) + 1/(1+jnp.exp(beta*(-(bilirubin_max/10 - 0.6)))) + 1/(1+jnp.exp(beta*(-(bilirubin_max/10 - 0.2)))) + 1/(1+jnp.exp(beta*(-(bilirubin_max/10 - 0.12))))
  return liver_sofa_cont

def h_sepsis_cont(treatment):
  respiration = h_respiration_cont(treatment[0],treatment[1])
  coagulation = h_coagulation_cont(treatment[2])
  liver = h_liver_cont(treatment[3])
  cardiovascular = h_cardiovascular_cont(treatment[4],treatment[5], treatment[6], treatment[7], treatment[8])
  cns = h_cns_cont(treatment[9])
  renal = h_renal_cont(treatment[10], treatment[11])
  sum_of_scores = respiration + coagulation + liver + cardiovascular + cns + renal
  sepsis_cont = 1/(1+jnp.exp(-(sum_of_scores - 2)))
  sepsis_label = 1/(1+jnp.exp(5*(-(sepsis_cont))))
  return sepsis_label

def h_sepsis_disc(patient_values):
  respiration = h_respiration_discrete_original(patient_values["respiration"][0][0],patient_values["respiration"][1][0])
  coagulation = h_coagulation_discrete_original(patient_values["coagulation"][0][0])
  liver = h_liver_discrete_original(patient_values["liver"][0][0])
  cardiovascular = h_cardiovascular_discrete_original(patient_values["cardiovascular"][0][0],patient_values["cardiovascular"][1][0], patient_values["cardiovascular"][2][0], patient_values["cardiovascular"][3][0], patient_values["cardiovascular"][4][0])
  cns = h_cns_discrete_original(patient_values["cns"][0][0])
  renal = h_renal_discrete_original(patient_values["renal"][0][0], patient_values["renal"][1][0])
  sofa_score = respiration + coagulation + liver + cardiovascular + cns + renal
  if sofa_score >= 2:
    return True
  return False


list_of_treatments = []
for patient in list_of_patient_values:
  patient_vals = []
  patient_vals.append(patient["respiration"][0][0])
  patient_vals.append(patient["respiration"][1][0])
  patient_vals.append(patient["coagulation"][0][0])
  patient_vals.append(patient["liver"][0][0])
  patient_vals.append(patient["cardiovascular"][0][0])
  patient_vals.append(patient["cardiovascular"][1][0])
  patient_vals.append(patient["cardiovascular"][2][0])
  patient_vals.append(patient["cardiovascular"][3][0])
  patient_vals.append(patient["cardiovascular"][4][0])
  patient_vals.append(patient["cns"][0][0])
  patient_vals.append(patient["renal"][0][0])
  patient_vals.append(patient["renal"][1][0])
  list_of_treatments.append(patient_vals)

# sepsis_real = []
# sepsis_model = []

# for i, patient in enumerate(list_of_patient_values):
#   if i<=10000:
#     if patient["sofa_score"] >= 2:
#       real = 1
#     else:
#       real = 0
#     model = h_sepsis_cont(list_of_treatments[i])
#     sepsis_real.append(real)
#     sepsis_model.append(model)

# plt.scatter(sepsis_real, sepsis_model)
# plt.show()

for i,treatment_entry in enumerate(list_of_treatments[7000:]):
  try:
    confounder_val = h_sepsis_cont(treatment_entry)
    confounder_idx = 7000 - i
    print("Confounder_Val: ", confounder_val)
    print("Confounder Idx: ", confounder_idx)
    print(i)
    break
  except Exception:
    continue

def flow_eqn(t, confounder):
  flow = jnp.power((h_sepsis_cont(t) - confounder), 2)
  return flow

gradient_flow_eqn = jax.grad(flow_eqn, 0)

#Define parameters
h = 0.1 # Step size
t = list_of_treatments # Numerical grid
s0 = [174.28571428571428, 461.5810187838212, 177.3667322567575, 0.8993936981348619, 0.0, 0.0, 0.0, 0.0, 88.0, 13.0, 0.8066873287215609, 1092.656875834446]
assert s0 != list_of_treatments[confounder_idx]

# Explicit Euler Method
s = []
s.append(s0)

t2_t = {"t2":list_of_treatments[confounder_idx],"confounder_value":float(confounder_val),"t*":s0}

with open("/content/attempt3_sepsis.json", "w+") as json_file:
  json.dump(t2_t, json_file)


for i in range(0, 500): 
  print(i)
  next = []
  gradients_to_subtract = []
  try:
    for j, gradient_entry in enumerate(gradient_flow_eqn(s[i],confounder_val)):
      gradients_to_subtract.append(h*gradient_entry)
    print("Gradients: ", gradients_to_subtract)
    for k,_ in enumerate(s[i]):
      next.append(s[i][k] - gradients_to_subtract[k])
    s.append(next)
  except Exception:
    current_val = s[i]
    s.append(current_val)
    continue

print(s[-1])

surrogate_treatment = []

for i,_ in enumerate(s[-1]):
  surrogate_treatment.append(s[-1][i])

t2_t["t*"] = surrogate_treatment

print("\n\nSurrogate Treatment: \n", surrogate_treatment)

# plt.figure(figsize = (12, 8))
# plt.plot(t, s, 'bo--', label='Approximate')
# plt.plot(t, -np.exp(-t), 'g', label='Exact')
# plt.title('Approximate and Exact Solution \
# for Simple ODE')
# plt.xlabel('t')
# plt.ylabel('f(t)')
# plt.grid()
# plt.legend(loc='lower right')
# plt.show()
# Out:
# 27139  values loaded!
# Confounder_Val:  0.9929335
# Confounder Idx:  7000
# 0
# 0
# Gradients:  [DeviceArray(-2.2477857e-15, dtype=float32), DeviceArray(5.6279744e-16, dtype=float32), DeviceArray(-1.5509972e-11, dtype=float32), DeviceArray(1.0100313e-09, dtype=float32), DeviceArray(7.120043e-15, dtype=float32), DeviceArray(1.1149396e-06, dtype=float32), DeviceArray(1.1149396e-06, dtype=float32), DeviceArray(7.119982e-14, dtype=float32), DeviceArray(-1.887189e-26, dtype=float32), DeviceArray(-1.1236322e-09, dtype=float32), DeviceArray(4.1953743e-09, dtype=float32), DeviceArray(1.6290262e-17, dtype=float32)]
# 1
# Gradients:  [DeviceArray(-2.2478063e-15, dtype=float32), DeviceArray(5.628035e-16, dtype=float32), DeviceArray(-1.5510137e-11, dtype=float32), DeviceArray(1.0100422e-09, dtype=float32), DeviceArray(7.121642e-15, dtype=float32), DeviceArray(1.114944e-06, dtype=float32), DeviceArray(1.114944e-06, dtype=float32), DeviceArray(7.121581e-14, dtype=float32), DeviceArray(-1.8876129e-26, dtype=float32), DeviceArray(-1.1236442e-09, dtype=float32), DeviceArray(4.19542e-09, dtype=float32), DeviceArray(1.6290439e-17, dtype=float32)]
# 2
# Gradients:  [DeviceArray(-2.2478291e-15, dtype=float32), DeviceArray(5.628098e-16, dtype=float32), DeviceArray(-1.5510312e-11, dtype=float32), DeviceArray(1.0100534e-09, dtype=float32), DeviceArray(7.123242e-15, dtype=float32), DeviceArray(1.1149485e-06, dtype=float32), DeviceArray(1.1149485e-06, dtype=float32), DeviceArray(7.123182e-14, dtype=float32), DeviceArray(-1.888037e-26, dtype=float32), DeviceArray(-1.1236567e-09, dtype=float32), DeviceArray(4.1954658e-09, dtype=float32), DeviceArray(1.6290624e-17, dtype=float32)]
# 3
# Gradients:  [DeviceArray(-2.2478558e-15, dtype=float32), DeviceArray(5.6281544e-16, dtype=float32), DeviceArray(-1.5510466e-11, dtype=float32), DeviceArray(1.0100635e-09, dtype=float32), DeviceArray(7.124782e-15, dtype=float32), DeviceArray(1.1149523e-06, dtype=float32), DeviceArray(1.1149523e-06, dtype=float32), DeviceArray(7.124721e-14, dtype=float32), DeviceArray(-1.8884447e-26, dtype=float32), DeviceArray(-1.1236679e-09, dtype=float32), DeviceArray(4.1955075e-09, dtype=float32), DeviceArray(1.6290784e-17, dtype=float32)]
# 4
# Gradients:  [DeviceArray(-2.247881e-15, dtype=float32), DeviceArray(5.628217e-16, dtype=float32), DeviceArray(-1.551064e-11, dtype=float32), DeviceArray(1.010075e-09, dtype=float32), DeviceArray(7.126384e-15, dtype=float32), DeviceArray(1.1149572e-06, dtype=float32), DeviceArray(1.1149572e-06, dtype=float32), DeviceArray(7.1263226e-14, dtype=float32), DeviceArray(-1.8888698e-26, dtype=float32), DeviceArray(-1.1236807e-09, dtype=float32), DeviceArray(4.1955563e-09, dtype=float32), DeviceArray(1.6290968e-17, dtype=float32)]
# 5
# Gradients:  [DeviceArray(-2.247903e-15, dtype=float32), DeviceArray(5.628277e-16, dtype=float32), DeviceArray(-1.5510806e-11, dtype=float32), DeviceArray(1.0100857e-09, dtype=float32), DeviceArray(7.127955e-15, dtype=float32), DeviceArray(1.1149613e-06, dtype=float32), DeviceArray(1.1149613e-06, dtype=float32), DeviceArray(7.127894e-14, dtype=float32), DeviceArray(-1.8892863e-26, dtype=float32), DeviceArray(-1.1236926e-09, dtype=float32), DeviceArray(4.1956016e-09, dtype=float32), DeviceArray(1.6291142e-17, dtype=float32)]
# 6
# Gradients:  [DeviceArray(-2.2479274e-15, dtype=float32), DeviceArray(5.628333e-16, dtype=float32), DeviceArray(-1.5510962e-11, dtype=float32), DeviceArray(1.0100958e-09, dtype=float32), DeviceArray(7.129523e-15, dtype=float32), DeviceArray(1.1149649e-06, dtype=float32), DeviceArray(1.1149649e-06, dtype=float32), DeviceArray(7.1294614e-14, dtype=float32), DeviceArray(-1.8897015e-26, dtype=float32), DeviceArray(-1.1237038e-09, dtype=float32), DeviceArray(4.1956434e-09, dtype=float32), DeviceArray(1.6291304e-17, dtype=float32)]
# 7
# Gradients:  [DeviceArray(-2.247952e-15, dtype=float32), DeviceArray(5.628399e-16, dtype=float32), DeviceArray(-1.5511146e-11, dtype=float32), DeviceArray(1.0101076e-09, dtype=float32), DeviceArray(7.131129e-15, dtype=float32), DeviceArray(1.1149701e-06, dtype=float32), DeviceArray(1.1149701e-06, dtype=float32), DeviceArray(7.131068e-14, dtype=float32), DeviceArray(-1.8901272e-26, dtype=float32), DeviceArray(-1.1237171e-09, dtype=float32), DeviceArray(4.195692e-09, dtype=float32), DeviceArray(1.6291493e-17, dtype=float32)]
# 8
# Gradients:  [DeviceArray(-2.2479753e-15, dtype=float32), DeviceArray(5.628458e-16, dtype=float32), DeviceArray(-1.5511306e-11, dtype=float32), DeviceArray(1.0101181e-09, dtype=float32), DeviceArray(7.132699e-15, dtype=float32), DeviceArray(1.1149743e-06, dtype=float32), DeviceArray(1.1149743e-06, dtype=float32), DeviceArray(7.132638e-14, dtype=float32), DeviceArray(-1.8905434e-26, dtype=float32), DeviceArray(-1.1237289e-09, dtype=float32), DeviceArray(4.195736e-09, dtype=float32), DeviceArray(1.6291665e-17, dtype=float32)]
# 9
# Gradients:  [DeviceArray(-2.2480015e-15, dtype=float32), DeviceArray(5.6285186e-16, dtype=float32), DeviceArray(-1.5511472e-11, dtype=float32), DeviceArray(1.010129e-09, dtype=float32), DeviceArray(7.134273e-15, dtype=float32), DeviceArray(1.1149787e-06, dtype=float32), DeviceArray(1.1149787e-06, dtype=float32), DeviceArray(7.134212e-14, dtype=float32), DeviceArray(-1.8909604e-26, dtype=float32), DeviceArray(-1.1237408e-09, dtype=float32), DeviceArray(4.1957806e-09, dtype=float32), DeviceArray(1.6291842e-17, dtype=float32)]
# 10
# Gradients:  [DeviceArray(-2.2480257e-15, dtype=float32), DeviceArray(5.62858e-16, dtype=float32), DeviceArray(-1.5511639e-11, dtype=float32), DeviceArray(1.0101399e-09, dtype=float32), DeviceArray(7.135874e-15, dtype=float32), DeviceArray(1.1149826e-06, dtype=float32), DeviceArray(1.1149826e-06, dtype=float32), DeviceArray(7.135812e-14, dtype=float32), DeviceArray(-1.8913848e-26, dtype=float32), DeviceArray(-1.123753e-09, dtype=float32), DeviceArray(4.195825e-09, dtype=float32), DeviceArray(1.6292015e-17, dtype=float32)]
# 11
# Gradients:  [DeviceArray(-2.2480494e-15, dtype=float32), DeviceArray(5.628638e-16, dtype=float32), DeviceArray(-1.5511804e-11, dtype=float32), DeviceArray(1.0101505e-09, dtype=float32), DeviceArray(7.137447e-15, dtype=float32), DeviceArray(1.1149872e-06, dtype=float32), DeviceArray(1.1149872e-06, dtype=float32), DeviceArray(7.1373856e-14, dtype=float32), DeviceArray(-1.8918017e-26, dtype=float32), DeviceArray(-1.1237649e-09, dtype=float32), DeviceArray(4.195871e-09, dtype=float32), DeviceArray(1.6292186e-17, dtype=float32)]
# 12
# Gradients:  [DeviceArray(-2.2480727e-15, dtype=float32), DeviceArray(5.628703e-16, dtype=float32), DeviceArray(-1.5511977e-11, dtype=float32), DeviceArray(1.010162e-09, dtype=float32), DeviceArray(7.139024e-15, dtype=float32), DeviceArray(1.1149917e-06, dtype=float32), DeviceArray(1.1149917e-06, dtype=float32), DeviceArray(7.138963e-14, dtype=float32), DeviceArray(-1.89222e-26, dtype=float32), DeviceArray(-1.1237775e-09, dtype=float32), DeviceArray(4.195916e-09, dtype=float32), DeviceArray(1.6292374e-17, dtype=float32)]
# 13
# Gradients:  [DeviceArray(-2.2480964e-15, dtype=float32), DeviceArray(5.628761e-16, dtype=float32), DeviceArray(-1.5512142e-11, dtype=float32), DeviceArray(1.0101726e-09, dtype=float32), DeviceArray(7.140626e-15, dtype=float32), DeviceArray(1.1149958e-06, dtype=float32), DeviceArray(1.1149958e-06, dtype=float32), DeviceArray(7.140564e-14, dtype=float32), DeviceArray(-1.8926445e-26, dtype=float32), DeviceArray(-1.1237893e-09, dtype=float32), DeviceArray(4.195962e-09, dtype=float32), DeviceArray(1.6292543e-17, dtype=float32)]
# 14
# Gradients:  [DeviceArray(-2.2481188e-15, dtype=float32), DeviceArray(5.628824e-16, dtype=float32), DeviceArray(-1.5512312e-11, dtype=float32), DeviceArray(1.0101836e-09, dtype=float32), DeviceArray(7.142229e-15, dtype=float32), DeviceArray(1.1150004e-06, dtype=float32), DeviceArray(1.1150004e-06, dtype=float32), DeviceArray(7.1421676e-14, dtype=float32), DeviceArray(-1.8930691e-26, dtype=float32), DeviceArray(-1.1238017e-09, dtype=float32), DeviceArray(4.1960075e-09, dtype=float32), DeviceArray(1.6292722e-17, dtype=float32)]
# 15
# Gradients:  [DeviceArray(-2.2481472e-15, dtype=float32), DeviceArray(5.628885e-16, dtype=float32), DeviceArray(-1.5512478e-11, dtype=float32), DeviceArray(1.0101946e-09, dtype=float32), DeviceArray(7.143777e-15, dtype=float32), DeviceArray(1.1150047e-06, dtype=float32), DeviceArray(1.1150047e-06, dtype=float32), DeviceArray(7.1437166e-14, dtype=float32), DeviceArray(-1.8934799e-26, dtype=float32), DeviceArray(-1.1238138e-09, dtype=float32), DeviceArray(4.1960533e-09, dtype=float32), DeviceArray(1.6292899e-17, dtype=float32)]
# 16
# Gradients:  [DeviceArray(-2.2481692e-15, dtype=float32), DeviceArray(5.628944e-16, dtype=float32), DeviceArray(-1.5512645e-11, dtype=float32), DeviceArray(1.0102054e-09, dtype=float32), DeviceArray(7.145379e-15, dtype=float32), DeviceArray(1.1150092e-06, dtype=float32), DeviceArray(1.1150092e-06, dtype=float32), DeviceArray(7.1453185e-14, dtype=float32), DeviceArray(-1.8939045e-26, dtype=float32), DeviceArray(-1.1238258e-09, dtype=float32), DeviceArray(4.1960977e-09, dtype=float32), DeviceArray(1.6293072e-17, dtype=float32)]
# 17
# Gradients:  [DeviceArray(-2.2481906e-15, dtype=float32), DeviceArray(5.629003e-16, dtype=float32), DeviceArray(-1.5512805e-11, dtype=float32), DeviceArray(1.0102159e-09, dtype=float32), DeviceArray(7.146927e-15, dtype=float32), DeviceArray(1.1150132e-06, dtype=float32), DeviceArray(1.1150132e-06, dtype=float32), DeviceArray(7.1468656e-14, dtype=float32), DeviceArray(-1.8943146e-26, dtype=float32), DeviceArray(-1.1238374e-09, dtype=float32), DeviceArray(4.1961417e-09, dtype=float32), DeviceArray(1.629324e-17, dtype=float32)]
# 18
# Gradients:  [DeviceArray(-2.248217e-15, dtype=float32), DeviceArray(5.6290633e-16, dtype=float32), DeviceArray(-1.5512976e-11, dtype=float32), DeviceArray(1.0102269e-09, dtype=float32), DeviceArray(7.148558e-15, dtype=float32), DeviceArray(1.1150174e-06, dtype=float32), DeviceArray(1.1150174e-06, dtype=float32), DeviceArray(7.148498e-14, dtype=float32), DeviceArray(-1.894747e-26, dtype=float32), DeviceArray(-1.1238498e-09, dtype=float32), DeviceArray(4.196188e-09, dtype=float32), DeviceArray(1.6293417e-17, dtype=float32)]
# 19
# Gradients:  [DeviceArray(-2.2482387e-15, dtype=float32), DeviceArray(5.629123e-16, dtype=float32), DeviceArray(-1.5513138e-11, dtype=float32), DeviceArray(1.0102376e-09, dtype=float32), DeviceArray(7.150106e-15, dtype=float32), DeviceArray(1.1150217e-06, dtype=float32), DeviceArray(1.1150217e-06, dtype=float32), DeviceArray(7.150044e-14, dtype=float32), DeviceArray(-1.8951571e-26, dtype=float32), DeviceArray(-1.1238616e-09, dtype=float32), DeviceArray(4.1962305e-09, dtype=float32), DeviceArray(1.629359e-17, dtype=float32)]
# 20
# Gradients:  [DeviceArray(-2.2482666e-15, dtype=float32), DeviceArray(5.629188e-16, dtype=float32), DeviceArray(-1.5513316e-11, dtype=float32), DeviceArray(1.0102491e-09, dtype=float32), DeviceArray(7.151744e-15, dtype=float32), DeviceArray(1.1150266e-06, dtype=float32), DeviceArray(1.1150266e-06, dtype=float32), DeviceArray(7.151683e-14, dtype=float32), DeviceArray(-1.8955915e-26, dtype=float32), DeviceArray(-1.1238745e-09, dtype=float32), DeviceArray(4.1962793e-09, dtype=float32), DeviceArray(1.6293779e-17, dtype=float32)]
# 21
# Gradients:  [DeviceArray(-2.248293e-15, dtype=float32), DeviceArray(5.6292497e-16, dtype=float32), DeviceArray(-1.5513486e-11, dtype=float32), DeviceArray(1.0102602e-09, dtype=float32), DeviceArray(7.153295e-15, dtype=float32), DeviceArray(1.1150314e-06, dtype=float32), DeviceArray(1.1150314e-06, dtype=float32), DeviceArray(7.1532346e-14, dtype=float32), DeviceArray(-1.8960025e-26, dtype=float32), DeviceArray(-1.1238868e-09, dtype=float32), DeviceArray(4.1963246e-09, dtype=float32), DeviceArray(1.6293954e-17, dtype=float32)]
# 22
# Gradients:  [DeviceArray(-2.248315e-15, dtype=float32), DeviceArray(5.629309e-16, dtype=float32), DeviceArray(-1.5513651e-11, dtype=float32), DeviceArray(1.0102709e-09, dtype=float32), DeviceArray(7.154898e-15, dtype=float32), DeviceArray(1.1150354e-06, dtype=float32), DeviceArray(1.1150354e-06, dtype=float32), DeviceArray(7.154837e-14, dtype=float32), DeviceArray(-1.8964276e-26, dtype=float32), DeviceArray(-1.1238986e-09, dtype=float32), DeviceArray(4.196369e-09, dtype=float32), DeviceArray(1.6294126e-17, dtype=float32)]
# 23
# Gradients:  [DeviceArray(-2.2483372e-15, dtype=float32), DeviceArray(5.629369e-16, dtype=float32), DeviceArray(-1.5513816e-11, dtype=float32), DeviceArray(1.0102816e-09, dtype=float32), DeviceArray(7.156505e-15, dtype=float32), DeviceArray(1.1150396e-06, dtype=float32), DeviceArray(1.1150396e-06, dtype=float32), DeviceArray(7.156444e-14, dtype=float32), DeviceArray(-1.8968532e-26, dtype=float32), DeviceArray(-1.1239106e-09, dtype=float32), DeviceArray(4.1964148e-09, dtype=float32), DeviceArray(1.6294302e-17, dtype=float32)]
# 24
# Gradients:  [DeviceArray(-2.2483666e-15, dtype=float32), DeviceArray(5.629433e-16, dtype=float32), DeviceArray(-1.5513991e-11, dtype=float32), DeviceArray(1.0102931e-09, dtype=float32), DeviceArray(7.15806e-15, dtype=float32), DeviceArray(1.1150447e-06, dtype=float32), DeviceArray(1.1150447e-06, dtype=float32), DeviceArray(7.157998e-14, dtype=float32), DeviceArray(-1.8972656e-26, dtype=float32), DeviceArray(-1.1239233e-09, dtype=float32), DeviceArray(4.1964614e-09, dtype=float32), DeviceArray(1.6294485e-17, dtype=float32)]
# 25
# Gradients:  [DeviceArray(-2.2483899e-15, dtype=float32), DeviceArray(5.6294906e-16, dtype=float32), DeviceArray(-1.5514154e-11, dtype=float32), DeviceArray(1.0103037e-09, dtype=float32), DeviceArray(7.159664e-15, dtype=float32), DeviceArray(1.1150481e-06, dtype=float32), DeviceArray(1.1150481e-06, dtype=float32), DeviceArray(7.159602e-14, dtype=float32), DeviceArray(-1.8976903e-26, dtype=float32), DeviceArray(-1.1239351e-09, dtype=float32), DeviceArray(4.196506e-09, dtype=float32), DeviceArray(1.6294657e-17, dtype=float32)]
# 26
# Gradients:  [DeviceArray(-2.2484117e-15, dtype=float32), DeviceArray(5.629551e-16, dtype=float32), DeviceArray(-1.5514317e-11, dtype=float32), DeviceArray(1.0103144e-09, dtype=float32), DeviceArray(7.161243e-15, dtype=float32), DeviceArray(1.1150527e-06, dtype=float32), DeviceArray(1.1150527e-06, dtype=float32), DeviceArray(7.161182e-14, dtype=float32), DeviceArray(-1.8981089e-26, dtype=float32), DeviceArray(-1.123947e-09, dtype=float32), DeviceArray(4.1965516e-09, dtype=float32), DeviceArray(1.6294826e-17, dtype=float32)]
# 27
# Gradients:  [DeviceArray(-2.2484354e-15, dtype=float32), DeviceArray(5.629611e-16, dtype=float32), DeviceArray(-1.5514482e-11, dtype=float32), DeviceArray(1.010325e-09, dtype=float32), DeviceArray(7.16282e-15, dtype=float32), DeviceArray(1.1150568e-06, dtype=float32), DeviceArray(1.1150568e-06, dtype=float32), DeviceArray(7.162759e-14, dtype=float32), DeviceArray(-1.8985269e-26, dtype=float32), DeviceArray(-1.1239589e-09, dtype=float32), DeviceArray(4.1965955e-09, dtype=float32), DeviceArray(1.6294997e-17, dtype=float32)]
# 28
# Gradients:  [DeviceArray(-2.248459e-15, dtype=float32), DeviceArray(5.629673e-16, dtype=float32), DeviceArray(-1.5514657e-11, dtype=float32), DeviceArray(1.0103364e-09, dtype=float32), DeviceArray(7.164431e-15, dtype=float32), DeviceArray(1.1150615e-06, dtype=float32), DeviceArray(1.1150615e-06, dtype=float32), DeviceArray(7.164369e-14, dtype=float32), DeviceArray(-1.898954e-26, dtype=float32), DeviceArray(-1.1239715e-09, dtype=float32), DeviceArray(4.1966426e-09, dtype=float32), DeviceArray(1.6295183e-17, dtype=float32)]
# 29
# Gradients:  [DeviceArray(-2.2484843e-15, dtype=float32), DeviceArray(5.629733e-16, dtype=float32), DeviceArray(-1.551482e-11, dtype=float32), DeviceArray(1.010347e-09, dtype=float32), DeviceArray(7.16601e-15, dtype=float32), DeviceArray(1.1150659e-06, dtype=float32), DeviceArray(1.1150659e-06, dtype=float32), DeviceArray(7.165948e-14, dtype=float32), DeviceArray(-1.8993723e-26, dtype=float32), DeviceArray(-1.1239835e-09, dtype=float32), DeviceArray(4.196686e-09, dtype=float32), DeviceArray(1.6295355e-17, dtype=float32)]
# 30
# Gradients:  [DeviceArray(-2.2485104e-15, dtype=float32), DeviceArray(5.629792e-16, dtype=float32), DeviceArray(-1.5514983e-11, dtype=float32), DeviceArray(1.0103576e-09, dtype=float32), DeviceArray(7.1675886e-15, dtype=float32), DeviceArray(1.1150697e-06, dtype=float32), DeviceArray(1.1150697e-06, dtype=float32), DeviceArray(7.167528e-14, dtype=float32), DeviceArray(-1.8997914e-26, dtype=float32), DeviceArray(-1.1239952e-09, dtype=float32), DeviceArray(4.1967305e-09, dtype=float32), DeviceArray(1.629553e-17, dtype=float32)]
# 31
# Gradients:  [DeviceArray(-2.2485343e-15, dtype=float32), DeviceArray(5.6298527e-16, dtype=float32), DeviceArray(-1.551515e-11, dtype=float32), DeviceArray(1.0103686e-09, dtype=float32), DeviceArray(7.169198e-15, dtype=float32), DeviceArray(1.1150743e-06, dtype=float32), DeviceArray(1.1150743e-06, dtype=float32), DeviceArray(7.169136e-14, dtype=float32), DeviceArray(-1.9002175e-26, dtype=float32), DeviceArray(-1.1240073e-09, dtype=float32), DeviceArray(4.196776e-09, dtype=float32), DeviceArray(1.6295703e-17, dtype=float32)]
# 32
# Gradients:  [DeviceArray(-2.246545e-15, dtype=float32), DeviceArray(5.6248806e-16, dtype=float32), DeviceArray(-1.5501446e-11, dtype=float32), DeviceArray(1.0094761e-09, dtype=float32), DeviceArray(7.164368e-15, dtype=float32), DeviceArray(1.1140817e-06, dtype=float32), DeviceArray(1.1140817e-06, dtype=float32), DeviceArray(7.164307e-14, dtype=float32), DeviceArray(-1.8989375e-26, dtype=float32), DeviceArray(-1.1230146e-09, dtype=float32), DeviceArray(4.1930686e-09, dtype=float32), DeviceArray(1.6281313e-17, dtype=float32)]
# 33
# Gradients:  [DeviceArray(-2.2465707e-15, dtype=float32), DeviceArray(5.62494e-16, dtype=float32), DeviceArray(-1.5501605e-11, dtype=float32), DeviceArray(1.0094866e-09, dtype=float32), DeviceArray(7.165973e-15, dtype=float32), DeviceArray(1.1140855e-06, dtype=float32), DeviceArray(1.1140855e-06, dtype=float32), DeviceArray(7.165912e-14, dtype=float32), DeviceArray(-1.8993629e-26, dtype=float32), DeviceArray(-1.1230263e-09, dtype=float32), DeviceArray(4.1931125e-09, dtype=float32), DeviceArray(1.6281482e-17, dtype=float32)]
# 34
# Gradients:  [DeviceArray(-2.246593e-15, dtype=float32), DeviceArray(5.625001e-16, dtype=float32), DeviceArray(-1.5501777e-11, dtype=float32), DeviceArray(1.0094976e-09, dtype=float32), DeviceArray(7.167555e-15, dtype=float32), DeviceArray(1.1140903e-06, dtype=float32), DeviceArray(1.1140903e-06, dtype=float32), DeviceArray(7.1674945e-14, dtype=float32), DeviceArray(-1.8997821e-26, dtype=float32), DeviceArray(-1.1230384e-09, dtype=float32), DeviceArray(4.193158e-09, dtype=float32), DeviceArray(1.6281659e-17, dtype=float32)]
# 35
# Gradients:  [DeviceArray(-2.2466208e-15, dtype=float32), DeviceArray(5.625065e-16, dtype=float32), DeviceArray(-1.5501952e-11, dtype=float32), DeviceArray(1.0095091e-09, dtype=float32), DeviceArray(7.16914e-15, dtype=float32), DeviceArray(1.1140952e-06, dtype=float32), DeviceArray(1.1140952e-06, dtype=float32), DeviceArray(7.16908e-14, dtype=float32), DeviceArray(-1.9002024e-26, dtype=float32), DeviceArray(-1.1230513e-09, dtype=float32), DeviceArray(4.1932062e-09, dtype=float32), DeviceArray(1.6281844e-17, dtype=float32)]
# 36
# Gradients:  [DeviceArray(-2.246647e-15, dtype=float32), DeviceArray(5.625125e-16, dtype=float32), DeviceArray(-1.5502122e-11, dtype=float32), DeviceArray(1.0095201e-09, dtype=float32), DeviceArray(7.170723e-15, dtype=float32), DeviceArray(1.1140995e-06, dtype=float32), DeviceArray(1.1140995e-06, dtype=float32), DeviceArray(7.170661e-14, dtype=float32), DeviceArray(-1.9006217e-26, dtype=float32), DeviceArray(-1.1230634e-09, dtype=float32), DeviceArray(4.193251e-09, dtype=float32), DeviceArray(1.6282023e-17, dtype=float32)]
# 37
# Gradients:  [DeviceArray(-2.2466679e-15, dtype=float32), DeviceArray(5.625183e-16, dtype=float32), DeviceArray(-1.550228e-11, dtype=float32), DeviceArray(1.0095305e-09, dtype=float32), DeviceArray(7.1723015e-15, dtype=float32), DeviceArray(1.1141036e-06, dtype=float32), DeviceArray(1.1141036e-06, dtype=float32), DeviceArray(7.1722406e-14, dtype=float32), DeviceArray(-1.90104e-26, dtype=float32), DeviceArray(-1.1230749e-09, dtype=float32), DeviceArray(4.193294e-09, dtype=float32), DeviceArray(1.6282188e-17, dtype=float32)]
# 38
# Gradients:  [DeviceArray(-2.2466905e-15, dtype=float32), DeviceArray(5.625245e-16, dtype=float32), DeviceArray(-1.550245e-11, dtype=float32), DeviceArray(1.0095415e-09, dtype=float32), DeviceArray(7.173912e-15, dtype=float32), DeviceArray(1.1141077e-06, dtype=float32), DeviceArray(1.1141077e-06, dtype=float32), DeviceArray(7.173851e-14, dtype=float32), DeviceArray(-1.9014671e-26, dtype=float32), DeviceArray(-1.1230873e-09, dtype=float32), DeviceArray(4.19334e-09, dtype=float32), DeviceArray(1.6282367e-17, dtype=float32)]
# 39
# Gradients:  [DeviceArray(-2.2467187e-15, dtype=float32), DeviceArray(5.625306e-16, dtype=float32), DeviceArray(-1.5502618e-11, dtype=float32), DeviceArray(1.0095523e-09, dtype=float32), DeviceArray(7.175494e-15, dtype=float32), DeviceArray(1.1141123e-06, dtype=float32), DeviceArray(1.1141123e-06, dtype=float32), DeviceArray(7.1754336e-14, dtype=float32), DeviceArray(-1.9018862e-26, dtype=float32), DeviceArray(-1.1230993e-09, dtype=float32), DeviceArray(4.193386e-09, dtype=float32), DeviceArray(1.6282539e-17, dtype=float32)]
# 40
# Gradients:  [DeviceArray(-2.2467407e-15, dtype=float32), DeviceArray(5.625366e-16, dtype=float32), DeviceArray(-1.5502781e-11, dtype=float32), DeviceArray(1.0095631e-09, dtype=float32), DeviceArray(7.177104e-15, dtype=float32), DeviceArray(1.1141163e-06, dtype=float32), DeviceArray(1.1141163e-06, dtype=float32), DeviceArray(7.1770437e-14, dtype=float32), DeviceArray(-1.902313e-26, dtype=float32), DeviceArray(-1.1231113e-09, dtype=float32), DeviceArray(4.1934296e-09, dtype=float32), DeviceArray(1.6282715e-17, dtype=float32)]
# 41
# Gradients:  [DeviceArray(-2.2467642e-15, dtype=float32), DeviceArray(5.625425e-16, dtype=float32), DeviceArray(-1.5502946e-11, dtype=float32), DeviceArray(1.0095738e-09, dtype=float32), DeviceArray(7.1786855e-15, dtype=float32), DeviceArray(1.1141203e-06, dtype=float32), DeviceArray(1.1141203e-06, dtype=float32), DeviceArray(7.178624e-14, dtype=float32), DeviceArray(-1.9027322e-26, dtype=float32), DeviceArray(-1.1231233e-09, dtype=float32), DeviceArray(4.1934736e-09, dtype=float32), DeviceArray(1.6282885e-17, dtype=float32)]
# 42
# Gradients:  [DeviceArray(-2.2467896e-15, dtype=float32), DeviceArray(5.6254883e-16, dtype=float32), DeviceArray(-1.5503118e-11, dtype=float32), DeviceArray(1.0095851e-09, dtype=float32), DeviceArray(7.180273e-15, dtype=float32), DeviceArray(1.1141254e-06, dtype=float32), DeviceArray(1.1141254e-06, dtype=float32), DeviceArray(7.180211e-14, dtype=float32), DeviceArray(-1.903153e-26, dtype=float32), DeviceArray(-1.1231357e-09, dtype=float32), DeviceArray(4.1935215e-09, dtype=float32), DeviceArray(1.6283069e-17, dtype=float32)]
# 43
# Gradients:  [DeviceArray(-2.2468152e-15, dtype=float32), DeviceArray(5.625548e-16, dtype=float32), DeviceArray(-1.5503284e-11, dtype=float32), DeviceArray(1.0095959e-09, dtype=float32), DeviceArray(7.181855e-15, dtype=float32), DeviceArray(1.1141295e-06, dtype=float32), DeviceArray(1.1141295e-06, dtype=float32), DeviceArray(7.181794e-14, dtype=float32), DeviceArray(-1.9035725e-26, dtype=float32), DeviceArray(-1.1231477e-09, dtype=float32), DeviceArray(4.1935655e-09, dtype=float32), DeviceArray(1.6283244e-17, dtype=float32)]
# 44
# Gradients:  [DeviceArray(-2.246839e-15, dtype=float32), DeviceArray(5.6256074e-16, dtype=float32), DeviceArray(-1.5503447e-11, dtype=float32), DeviceArray(1.0096065e-09, dtype=float32), DeviceArray(7.183437e-15, dtype=float32), DeviceArray(1.1141335e-06, dtype=float32), DeviceArray(1.1141335e-06, dtype=float32), DeviceArray(7.183376e-14, dtype=float32), DeviceArray(-1.9039919e-26, dtype=float32), DeviceArray(-1.1231596e-09, dtype=float32), DeviceArray(4.1936103e-09, dtype=float32), DeviceArray(1.6283413e-17, dtype=float32)]
# 45
# Gradients:  [DeviceArray(-2.2468614e-15, dtype=float32), DeviceArray(5.6256683e-16, dtype=float32), DeviceArray(-1.5503614e-11, dtype=float32), DeviceArray(1.0096173e-09, dtype=float32), DeviceArray(7.185023e-15, dtype=float32), DeviceArray(1.114138e-06, dtype=float32), DeviceArray(1.114138e-06, dtype=float32), DeviceArray(7.184961e-14, dtype=float32), DeviceArray(-1.9044118e-26, dtype=float32), DeviceArray(-1.1231716e-09, dtype=float32), DeviceArray(4.1936548e-09, dtype=float32), DeviceArray(1.6283588e-17, dtype=float32)]
# 46
# Gradients:  [DeviceArray(-2.246886e-15, dtype=float32), DeviceArray(5.6257297e-16, dtype=float32), DeviceArray(-1.5503787e-11, dtype=float32), DeviceArray(1.0096285e-09, dtype=float32), DeviceArray(7.186665e-15, dtype=float32), DeviceArray(1.1141424e-06, dtype=float32), DeviceArray(1.1141424e-06, dtype=float32), DeviceArray(7.186603e-14, dtype=float32), DeviceArray(-1.9048473e-26, dtype=float32), DeviceArray(-1.1231841e-09, dtype=float32), DeviceArray(4.193701e-09, dtype=float32), DeviceArray(1.6283768e-17, dtype=float32)]
# 47
# Gradients:  [DeviceArray(-2.2469097e-15, dtype=float32), DeviceArray(5.625789e-16, dtype=float32), DeviceArray(-1.550395e-11, dtype=float32), DeviceArray(1.0096392e-09, dtype=float32), DeviceArray(7.188222e-15, dtype=float32), DeviceArray(1.1141467e-06, dtype=float32), DeviceArray(1.1141467e-06, dtype=float32), DeviceArray(7.18816e-14, dtype=float32), DeviceArray(-1.9052601e-26, dtype=float32), DeviceArray(-1.1231959e-09, dtype=float32), DeviceArray(4.1937454e-09, dtype=float32), DeviceArray(1.628394e-17, dtype=float32)]
# 48
# Gradients:  [DeviceArray(-2.246933e-15, dtype=float32), DeviceArray(5.625853e-16, dtype=float32), DeviceArray(-1.5504127e-11, dtype=float32), DeviceArray(1.0096505e-09, dtype=float32), DeviceArray(7.1898384e-15, dtype=float32), DeviceArray(1.1141517e-06, dtype=float32), DeviceArray(1.1141517e-06, dtype=float32), DeviceArray(7.1897776e-14, dtype=float32), DeviceArray(-1.9056886e-26, dtype=float32), DeviceArray(-1.1232087e-09, dtype=float32), DeviceArray(4.1937938e-09, dtype=float32), DeviceArray(1.6284122e-17, dtype=float32)]
# 49
# Gradients:  [DeviceArray(-2.246959e-15, dtype=float32), DeviceArray(5.6259124e-16, dtype=float32), DeviceArray(-1.5504289e-11, dtype=float32), DeviceArray(1.0096611e-09, dtype=float32), DeviceArray(7.1914495e-15, dtype=float32), DeviceArray(1.1141555e-06, dtype=float32), DeviceArray(1.1141555e-06, dtype=float32), DeviceArray(7.1913876e-14, dtype=float32), DeviceArray(-1.9061152e-26, dtype=float32), DeviceArray(-1.1232205e-09, dtype=float32), DeviceArray(4.1938373e-09, dtype=float32), DeviceArray(1.62843e-17, dtype=float32)]
# 50
# Gradients:  [DeviceArray(-2.2469825e-15, dtype=float32), DeviceArray(5.625971e-16, dtype=float32), DeviceArray(-1.5504454e-11, dtype=float32), DeviceArray(1.0096719e-09, dtype=float32), DeviceArray(7.193009e-15, dtype=float32), DeviceArray(1.11416e-06, dtype=float32), DeviceArray(1.11416e-06, dtype=float32), DeviceArray(7.192947e-14, dtype=float32), DeviceArray(-1.9065287e-26, dtype=float32), DeviceArray(-1.1232324e-09, dtype=float32), DeviceArray(4.193882e-09, dtype=float32), DeviceArray(1.628447e-17, dtype=float32)]
# 51
# Gradients:  [DeviceArray(-2.2470065e-15, dtype=float32), DeviceArray(5.6260304e-16, dtype=float32), DeviceArray(-1.5504617e-11, dtype=float32), DeviceArray(1.0096826e-09, dtype=float32), DeviceArray(7.194593e-15, dtype=float32), DeviceArray(1.1141641e-06, dtype=float32), DeviceArray(1.1141641e-06, dtype=float32), DeviceArray(7.1945325e-14, dtype=float32), DeviceArray(-1.9069489e-26, dtype=float32), DeviceArray(-1.1232442e-09, dtype=float32), DeviceArray(4.193927e-09, dtype=float32), DeviceArray(1.6284637e-17, dtype=float32)]
# 52
# Gradients:  [DeviceArray(-2.2470312e-15, dtype=float32), DeviceArray(5.6260934e-16, dtype=float32), DeviceArray(-1.550479e-11, dtype=float32), DeviceArray(1.0096938e-09, dtype=float32), DeviceArray(7.19621e-15, dtype=float32), DeviceArray(1.1141686e-06, dtype=float32), DeviceArray(1.1141686e-06, dtype=float32), DeviceArray(7.196148e-14, dtype=float32), DeviceArray(-1.9073774e-26, dtype=float32), DeviceArray(-1.1232566e-09, dtype=float32), DeviceArray(4.1939727e-09, dtype=float32), DeviceArray(1.6284822e-17, dtype=float32)]
# 53
# Gradients:  [DeviceArray(-2.2470545e-15, dtype=float32), DeviceArray(5.626152e-16, dtype=float32), DeviceArray(-1.5504948e-11, dtype=float32), DeviceArray(1.0097042e-09, dtype=float32), DeviceArray(7.197794e-15, dtype=float32), DeviceArray(1.1141726e-06, dtype=float32), DeviceArray(1.1141726e-06, dtype=float32), DeviceArray(7.197732e-14, dtype=float32), DeviceArray(-1.9077971e-26, dtype=float32), DeviceArray(-1.1232683e-09, dtype=float32), DeviceArray(4.194016e-09, dtype=float32), DeviceArray(1.6284993e-17, dtype=float32)]
# 54
# Gradients:  [DeviceArray(-2.2470802e-15, dtype=float32), DeviceArray(5.626216e-16, dtype=float32), DeviceArray(-1.5505127e-11, dtype=float32), DeviceArray(1.0097159e-09, dtype=float32), DeviceArray(7.199416e-15, dtype=float32), DeviceArray(1.1141775e-06, dtype=float32), DeviceArray(1.1141775e-06, dtype=float32), DeviceArray(7.199353e-14, dtype=float32), DeviceArray(-1.908227e-26, dtype=float32), DeviceArray(-1.1232812e-09, dtype=float32), DeviceArray(4.1940647e-09, dtype=float32), DeviceArray(1.6285173e-17, dtype=float32)]
# 55
# Gradients:  [DeviceArray(-2.247104e-15, dtype=float32), DeviceArray(5.626275e-16, dtype=float32), DeviceArray(-1.550529e-11, dtype=float32), DeviceArray(1.0097264e-09, dtype=float32), DeviceArray(7.201002e-15, dtype=float32), DeviceArray(1.1141817e-06, dtype=float32), DeviceArray(1.1141817e-06, dtype=float32), DeviceArray(7.2009395e-14, dtype=float32), DeviceArray(-1.9086473e-26, dtype=float32), DeviceArray(-1.1232929e-09, dtype=float32), DeviceArray(4.1941073e-09, dtype=float32), DeviceArray(1.6285347e-17, dtype=float32)]
# 56
# Gradients:  [DeviceArray(-2.2471303e-15, dtype=float32), DeviceArray(5.626337e-16, dtype=float32), DeviceArray(-1.550546e-11, dtype=float32), DeviceArray(1.0097374e-09, dtype=float32), DeviceArray(7.2025905e-15, dtype=float32), DeviceArray(1.1141863e-06, dtype=float32), DeviceArray(1.1141863e-06, dtype=float32), DeviceArray(7.2025285e-14, dtype=float32), DeviceArray(-1.9090684e-26, dtype=float32), DeviceArray(-1.1233052e-09, dtype=float32), DeviceArray(4.194154e-09, dtype=float32), DeviceArray(1.6285524e-17, dtype=float32)]
# 57
# Gradients:  [DeviceArray(-2.2471515e-15, dtype=float32), DeviceArray(5.6263946e-16, dtype=float32), DeviceArray(-1.550562e-11, dtype=float32), DeviceArray(1.0097478e-09, dtype=float32), DeviceArray(7.204204e-15, dtype=float32), DeviceArray(1.1141899e-06, dtype=float32), DeviceArray(1.1141899e-06, dtype=float32), DeviceArray(7.204143e-14, dtype=float32), DeviceArray(-1.9094959e-26, dtype=float32), DeviceArray(-1.1233169e-09, dtype=float32), DeviceArray(4.1941974e-09, dtype=float32), DeviceArray(1.6285694e-17, dtype=float32)]
# 58
# Gradients:  [DeviceArray(-2.2471757e-15, dtype=float32), DeviceArray(5.626455e-16, dtype=float32), DeviceArray(-1.5505786e-11, dtype=float32), DeviceArray(1.0097587e-09, dtype=float32), DeviceArray(7.205795e-15, dtype=float32), DeviceArray(1.1141946e-06, dtype=float32), DeviceArray(1.1141946e-06, dtype=float32), DeviceArray(7.205732e-14, dtype=float32), DeviceArray(-1.9099175e-26, dtype=float32), DeviceArray(-1.1233289e-09, dtype=float32), DeviceArray(4.1942427e-09, dtype=float32), DeviceArray(1.6285866e-17, dtype=float32)]
# 59
# Gradients:  [DeviceArray(-2.2472021e-15, dtype=float32), DeviceArray(5.6265164e-16, dtype=float32), DeviceArray(-1.550595e-11, dtype=float32), DeviceArray(1.0097695e-09, dtype=float32), DeviceArray(7.207383e-15, dtype=float32), DeviceArray(1.1141987e-06, dtype=float32), DeviceArray(1.1141987e-06, dtype=float32), DeviceArray(7.207321e-14, dtype=float32), DeviceArray(-1.9103387e-26, dtype=float32), DeviceArray(-1.123341e-09, dtype=float32), DeviceArray(4.1942876e-09, dtype=float32), DeviceArray(1.6286045e-17, dtype=float32)]
# 60
# Gradients:  [DeviceArray(-2.2472225e-15, dtype=float32), DeviceArray(5.626579e-16, dtype=float32), DeviceArray(-1.5506122e-11, dtype=float32), DeviceArray(1.0097806e-09, dtype=float32), DeviceArray(7.209002e-15, dtype=float32), DeviceArray(1.1142034e-06, dtype=float32), DeviceArray(1.1142034e-06, dtype=float32), DeviceArray(7.2089395e-14, dtype=float32), DeviceArray(-1.9107676e-26, dtype=float32), DeviceArray(-1.1233533e-09, dtype=float32), DeviceArray(4.1943338e-09, dtype=float32), DeviceArray(1.6286223e-17, dtype=float32)]
# 61
# Gradients:  [DeviceArray(-2.2472487e-15, dtype=float32), DeviceArray(5.6266376e-16, dtype=float32), DeviceArray(-1.5506292e-11, dtype=float32), DeviceArray(1.0097916e-09, dtype=float32), DeviceArray(7.2105645e-15, dtype=float32), DeviceArray(1.1142077e-06, dtype=float32), DeviceArray(1.1142077e-06, dtype=float32), DeviceArray(7.210502e-14, dtype=float32), DeviceArray(-1.9111818e-26, dtype=float32), DeviceArray(-1.1233654e-09, dtype=float32), DeviceArray(4.1943795e-09, dtype=float32), DeviceArray(1.6286397e-17, dtype=float32)]
# 62
# Gradients:  [DeviceArray(-2.247274e-15, dtype=float32), DeviceArray(5.626701e-16, dtype=float32), DeviceArray(-1.5506464e-11, dtype=float32), DeviceArray(1.0098029e-09, dtype=float32), DeviceArray(7.2121865e-15, dtype=float32), DeviceArray(1.1142123e-06, dtype=float32), DeviceArray(1.1142123e-06, dtype=float32), DeviceArray(7.2121244e-14, dtype=float32), DeviceArray(-1.9116117e-26, dtype=float32), DeviceArray(-1.1233781e-09, dtype=float32), DeviceArray(4.1944257e-09, dtype=float32), DeviceArray(1.628658e-17, dtype=float32)]
# 63
# Gradients:  [DeviceArray(-2.2472976e-15, dtype=float32), DeviceArray(5.626761e-16, dtype=float32), DeviceArray(-1.5506627e-11, dtype=float32), DeviceArray(1.0098135e-09, dtype=float32), DeviceArray(7.213776e-15, dtype=float32), DeviceArray(1.1142165e-06, dtype=float32), DeviceArray(1.1142165e-06, dtype=float32), DeviceArray(7.2137134e-14, dtype=float32), DeviceArray(-1.912033e-26, dtype=float32), DeviceArray(-1.1233897e-09, dtype=float32), DeviceArray(4.19447e-09, dtype=float32), DeviceArray(1.6286748e-17, dtype=float32)]
# 64
# Gradients:  [DeviceArray(-2.2473256e-15, dtype=float32), DeviceArray(5.6268203e-16, dtype=float32), DeviceArray(-1.5506794e-11, dtype=float32), DeviceArray(1.0098242e-09, dtype=float32), DeviceArray(7.2153655e-15, dtype=float32), DeviceArray(1.1142207e-06, dtype=float32), DeviceArray(1.1142207e-06, dtype=float32), DeviceArray(7.215304e-14, dtype=float32), DeviceArray(-1.9124544e-26, dtype=float32), DeviceArray(-1.1234017e-09, dtype=float32), DeviceArray(4.194515e-09, dtype=float32), DeviceArray(1.6286923e-17, dtype=float32)]
# 65
# Gradients:  [DeviceArray(-2.2473457e-15, dtype=float32), DeviceArray(5.6268806e-16, dtype=float32), DeviceArray(-1.5506959e-11, dtype=float32), DeviceArray(1.0098351e-09, dtype=float32), DeviceArray(7.216985e-15, dtype=float32), DeviceArray(1.1142251e-06, dtype=float32), DeviceArray(1.1142251e-06, dtype=float32), DeviceArray(7.216923e-14, dtype=float32), DeviceArray(-1.9128837e-26, dtype=float32), DeviceArray(-1.1234139e-09, dtype=float32), DeviceArray(4.194559e-09, dtype=float32), DeviceArray(1.6287099e-17, dtype=float32)]
# 66
# Gradients:  [DeviceArray(-2.247369e-15, dtype=float32), DeviceArray(5.6269405e-16, dtype=float32), DeviceArray(-1.550712e-11, dtype=float32), DeviceArray(1.0098457e-09, dtype=float32), DeviceArray(7.218548e-15, dtype=float32), DeviceArray(1.1142293e-06, dtype=float32), DeviceArray(1.1142293e-06, dtype=float32), DeviceArray(7.2184846e-14, dtype=float32), DeviceArray(-1.9132975e-26, dtype=float32), DeviceArray(-1.1234257e-09, dtype=float32), DeviceArray(4.1946033e-09, dtype=float32), DeviceArray(1.6287269e-17, dtype=float32)]
# 67
# Gradients:  [DeviceArray(-2.2473963e-15, dtype=float32), DeviceArray(5.6270024e-16, dtype=float32), DeviceArray(-1.5507295e-11, dtype=float32), DeviceArray(1.009857e-09, dtype=float32), DeviceArray(7.2201995e-15, dtype=float32), DeviceArray(1.1142337e-06, dtype=float32), DeviceArray(1.1142337e-06, dtype=float32), DeviceArray(7.2201366e-14, dtype=float32), DeviceArray(-1.9137354e-26, dtype=float32), DeviceArray(-1.1234382e-09, dtype=float32), DeviceArray(4.19465e-09, dtype=float32), DeviceArray(1.6287454e-17, dtype=float32)]
# 68
# Gradients:  [DeviceArray(-2.2474192e-15, dtype=float32), DeviceArray(5.6270643e-16, dtype=float32), DeviceArray(-1.5507467e-11, dtype=float32), DeviceArray(1.0098681e-09, dtype=float32), DeviceArray(7.221793e-15, dtype=float32), DeviceArray(1.1142386e-06, dtype=float32), DeviceArray(1.1142386e-06, dtype=float32), DeviceArray(7.2217304e-14, dtype=float32), DeviceArray(-1.9141577e-26, dtype=float32), DeviceArray(-1.1234507e-09, dtype=float32), DeviceArray(4.194697e-09, dtype=float32), DeviceArray(1.628763e-17, dtype=float32)]
# 69
# Gradients:  [DeviceArray(-2.2474431e-15, dtype=float32), DeviceArray(5.627125e-16, dtype=float32), DeviceArray(-1.5507628e-11, dtype=float32), DeviceArray(1.0098788e-09, dtype=float32), DeviceArray(7.223386e-15, dtype=float32), DeviceArray(1.1142428e-06, dtype=float32), DeviceArray(1.1142428e-06, dtype=float32), DeviceArray(7.2233235e-14, dtype=float32), DeviceArray(-1.91458e-26, dtype=float32), DeviceArray(-1.1234625e-09, dtype=float32), DeviceArray(4.1947414e-09, dtype=float32), DeviceArray(1.6287808e-17, dtype=float32)]
# 70
# Gradients:  [DeviceArray(-2.2474694e-15, dtype=float32), DeviceArray(5.627185e-16, dtype=float32), DeviceArray(-1.55078e-11, dtype=float32), DeviceArray(1.0098898e-09, dtype=float32), DeviceArray(7.22498e-15, dtype=float32), DeviceArray(1.1142472e-06, dtype=float32), DeviceArray(1.1142472e-06, dtype=float32), DeviceArray(7.224917e-14, dtype=float32), DeviceArray(-1.9150022e-26, dtype=float32), DeviceArray(-1.1234749e-09, dtype=float32), DeviceArray(4.194787e-09, dtype=float32), DeviceArray(1.6287985e-17, dtype=float32)]
# 71
# Gradients:  [DeviceArray(-2.247493e-15, dtype=float32), DeviceArray(5.627246e-16, dtype=float32), DeviceArray(-1.5507961e-11, dtype=float32), DeviceArray(1.0099005e-09, dtype=float32), DeviceArray(7.2265726e-15, dtype=float32), DeviceArray(1.1142514e-06, dtype=float32), DeviceArray(1.1142514e-06, dtype=float32), DeviceArray(7.226509e-14, dtype=float32), DeviceArray(-1.9154245e-26, dtype=float32), DeviceArray(-1.1234866e-09, dtype=float32), DeviceArray(4.1948307e-09, dtype=float32), DeviceArray(1.6288156e-17, dtype=float32)]
# 72
# Gradients:  [DeviceArray(-2.2475168e-15, dtype=float32), DeviceArray(5.6273047e-16, dtype=float32), DeviceArray(-1.5508128e-11, dtype=float32), DeviceArray(1.0099112e-09, dtype=float32), DeviceArray(7.228165e-15, dtype=float32), DeviceArray(1.1142555e-06, dtype=float32), DeviceArray(1.1142555e-06, dtype=float32), DeviceArray(7.228102e-14, dtype=float32), DeviceArray(-1.9158465e-26, dtype=float32), DeviceArray(-1.1234985e-09, dtype=float32), DeviceArray(4.194876e-09, dtype=float32), DeviceArray(1.6288324e-17, dtype=float32)]
# 73
# Gradients:  [DeviceArray(-2.2475403e-15, dtype=float32), DeviceArray(5.6273687e-16, dtype=float32), DeviceArray(-1.5508301e-11, dtype=float32), DeviceArray(1.0099226e-09, dtype=float32), DeviceArray(7.2297904e-15, dtype=float32), DeviceArray(1.1142602e-06, dtype=float32), DeviceArray(1.1142602e-06, dtype=float32), DeviceArray(7.229728e-14, dtype=float32), DeviceArray(-1.9162773e-26, dtype=float32), DeviceArray(-1.1235111e-09, dtype=float32), DeviceArray(4.194923e-09, dtype=float32), DeviceArray(1.6288511e-17, dtype=float32)]
# 74
# Gradients:  [DeviceArray(-2.2475636e-15, dtype=float32), DeviceArray(5.6274264e-16, dtype=float32), DeviceArray(-1.5508463e-11, dtype=float32), DeviceArray(1.009933e-09, dtype=float32), DeviceArray(7.231384e-15, dtype=float32), DeviceArray(1.1142644e-06, dtype=float32), DeviceArray(1.1142644e-06, dtype=float32), DeviceArray(7.23132e-14, dtype=float32), DeviceArray(-1.9166998e-26, dtype=float32), DeviceArray(-1.1235228e-09, dtype=float32), DeviceArray(4.194967e-09, dtype=float32), DeviceArray(1.6288683e-17, dtype=float32)]
# 75
# Gradients:  [DeviceArray(-2.2475894e-15, dtype=float32), DeviceArray(5.627487e-16, dtype=float32), DeviceArray(-1.5508629e-11, dtype=float32), DeviceArray(1.0099439e-09, dtype=float32), DeviceArray(7.233004e-15, dtype=float32), DeviceArray(1.1142683e-06, dtype=float32), DeviceArray(1.1142683e-06, dtype=float32), DeviceArray(7.232942e-14, dtype=float32), DeviceArray(-1.9171292e-26, dtype=float32), DeviceArray(-1.1235348e-09, dtype=float32), DeviceArray(4.195011e-09, dtype=float32), DeviceArray(1.6288856e-17, dtype=float32)]
# 76
# Gradients:  [DeviceArray(-2.24761e-15, dtype=float32), DeviceArray(5.627548e-16, dtype=float32), DeviceArray(-1.55088e-11, dtype=float32), DeviceArray(1.0099548e-09, dtype=float32), DeviceArray(7.2346e-15, dtype=float32), DeviceArray(1.1142728e-06, dtype=float32), DeviceArray(1.1142728e-06, dtype=float32), DeviceArray(7.2345375e-14, dtype=float32), DeviceArray(-1.9175525e-26, dtype=float32), DeviceArray(-1.123547e-09, dtype=float32), DeviceArray(4.1950567e-09, dtype=float32), DeviceArray(1.6289031e-17, dtype=float32)]
# 77
# Gradients:  [DeviceArray(-2.2476356e-15, dtype=float32), DeviceArray(5.6276075e-16, dtype=float32), DeviceArray(-1.550896e-11, dtype=float32), DeviceArray(1.0099654e-09, dtype=float32), DeviceArray(7.236195e-15, dtype=float32), DeviceArray(1.114277e-06, dtype=float32), DeviceArray(1.114277e-06, dtype=float32), DeviceArray(7.236133e-14, dtype=float32), DeviceArray(-1.9179751e-26, dtype=float32), DeviceArray(-1.1235589e-09, dtype=float32), DeviceArray(4.1951e-09, dtype=float32), DeviceArray(1.6289206e-17, dtype=float32)]
# 78
# Gradients:  [DeviceArray(-2.245649e-15, dtype=float32), DeviceArray(5.6226365e-16, dtype=float32), DeviceArray(-1.5495261e-11, dtype=float32), DeviceArray(1.0090734e-09, dtype=float32), DeviceArray(7.231376e-15, dtype=float32), DeviceArray(1.1132851e-06, dtype=float32), DeviceArray(1.1132851e-06, dtype=float32), DeviceArray(7.2313134e-14, dtype=float32), DeviceArray(-1.9166977e-26, dtype=float32), DeviceArray(-1.1225664e-09, dtype=float32), DeviceArray(4.1913952e-09, dtype=float32), DeviceArray(1.6274818e-17, dtype=float32)]
# 79
# Gradients:  [DeviceArray(-2.245673e-15, dtype=float32), DeviceArray(5.6226947e-16, dtype=float32), DeviceArray(-1.5495423e-11, dtype=float32), DeviceArray(1.0090838e-09, dtype=float32), DeviceArray(7.2329405e-15, dtype=float32), DeviceArray(1.1132892e-06, dtype=float32), DeviceArray(1.1132892e-06, dtype=float32), DeviceArray(7.232878e-14, dtype=float32), DeviceArray(-1.9171127e-26, dtype=float32), DeviceArray(-1.1225781e-09, dtype=float32), DeviceArray(4.1914396e-09, dtype=float32), DeviceArray(1.6274985e-17, dtype=float32)]
# 80
# Gradients:  [DeviceArray(-2.2456976e-15, dtype=float32), DeviceArray(5.6227566e-16, dtype=float32), DeviceArray(-1.5495596e-11, dtype=float32), DeviceArray(1.009095e-09, dtype=float32), DeviceArray(7.234566e-15, dtype=float32), DeviceArray(1.1132936e-06, dtype=float32), DeviceArray(1.1132936e-06, dtype=float32), DeviceArray(7.234504e-14, dtype=float32), DeviceArray(-1.9175435e-26, dtype=float32), DeviceArray(-1.1225907e-09, dtype=float32), DeviceArray(4.1914854e-09, dtype=float32), DeviceArray(1.627517e-17, dtype=float32)]
# 81
# Gradients:  [DeviceArray(-2.2457213e-15, dtype=float32), DeviceArray(5.622817e-16, dtype=float32), DeviceArray(-1.5495761e-11, dtype=float32), DeviceArray(1.0091059e-09, dtype=float32), DeviceArray(7.236134e-15, dtype=float32), DeviceArray(1.1132979e-06, dtype=float32), DeviceArray(1.1132979e-06, dtype=float32), DeviceArray(7.236072e-14, dtype=float32), DeviceArray(-1.917959e-26, dtype=float32), DeviceArray(-1.1226027e-09, dtype=float32), DeviceArray(4.1915302e-09, dtype=float32), DeviceArray(1.6275341e-17, dtype=float32)]
# 82
# Gradients:  [DeviceArray(-2.2457442e-15, dtype=float32), DeviceArray(5.622874e-16, dtype=float32), DeviceArray(-1.5495915e-11, dtype=float32), DeviceArray(1.0091158e-09, dtype=float32), DeviceArray(7.237725e-15, dtype=float32), DeviceArray(1.1133016e-06, dtype=float32), DeviceArray(1.1133016e-06, dtype=float32), DeviceArray(7.237662e-14, dtype=float32), DeviceArray(-1.9183808e-26, dtype=float32), DeviceArray(-1.1226137e-09, dtype=float32), DeviceArray(4.1915724e-09, dtype=float32), DeviceArray(1.6275505e-17, dtype=float32)]
# 83
# Gradients:  [DeviceArray(-2.245769e-15, dtype=float32), DeviceArray(5.622937e-16, dtype=float32), DeviceArray(-1.5496089e-11, dtype=float32), DeviceArray(1.0091272e-09, dtype=float32), DeviceArray(7.239353e-15, dtype=float32), DeviceArray(1.1133061e-06, dtype=float32), DeviceArray(1.1133061e-06, dtype=float32), DeviceArray(7.239289e-14, dtype=float32), DeviceArray(-1.9188119e-26, dtype=float32), DeviceArray(-1.1226263e-09, dtype=float32), DeviceArray(4.1916195e-09, dtype=float32), DeviceArray(1.6275687e-17, dtype=float32)]
# 84
# Gradients:  [DeviceArray(-2.245795e-15, dtype=float32), DeviceArray(5.6229965e-16, dtype=float32), DeviceArray(-1.5496254e-11, dtype=float32), DeviceArray(1.0091381e-09, dtype=float32), DeviceArray(7.240948e-15, dtype=float32), DeviceArray(1.1133106e-06, dtype=float32), DeviceArray(1.1133106e-06, dtype=float32), DeviceArray(7.240887e-14, dtype=float32), DeviceArray(-1.9192354e-26, dtype=float32), DeviceArray(-1.1226385e-09, dtype=float32), DeviceArray(4.1916643e-09, dtype=float32), DeviceArray(1.6275862e-17, dtype=float32)]
# 85
# Gradients:  [DeviceArray(-2.2458191e-15, dtype=float32), DeviceArray(5.623057e-16, dtype=float32), DeviceArray(-1.549642e-11, dtype=float32), DeviceArray(1.0091487e-09, dtype=float32), DeviceArray(7.242572e-15, dtype=float32), DeviceArray(1.1133146e-06, dtype=float32), DeviceArray(1.1133146e-06, dtype=float32), DeviceArray(7.24251e-14, dtype=float32), DeviceArray(-1.9196654e-26, dtype=float32), DeviceArray(-1.1226503e-09, dtype=float32), DeviceArray(4.1917083e-09, dtype=float32), DeviceArray(1.6276034e-17, dtype=float32)]
# 86
# Gradients:  [DeviceArray(-2.2458424e-15, dtype=float32), DeviceArray(5.623119e-16, dtype=float32), DeviceArray(-1.5496594e-11, dtype=float32), DeviceArray(1.00916e-09, dtype=float32), DeviceArray(7.244172e-15, dtype=float32), DeviceArray(1.1133194e-06, dtype=float32), DeviceArray(1.1133194e-06, dtype=float32), DeviceArray(7.2441104e-14, dtype=float32), DeviceArray(-1.9200898e-26, dtype=float32), DeviceArray(-1.1226629e-09, dtype=float32), DeviceArray(4.1917563e-09, dtype=float32), DeviceArray(1.6276213e-17, dtype=float32)]
# 87
# Gradients:  [DeviceArray(-2.2458647e-15, dtype=float32), DeviceArray(5.623177e-16, dtype=float32), DeviceArray(-1.5496748e-11, dtype=float32), DeviceArray(1.0091702e-09, dtype=float32), DeviceArray(7.2457655e-15, dtype=float32), DeviceArray(1.1133233e-06, dtype=float32), DeviceArray(1.1133233e-06, dtype=float32), DeviceArray(7.2457035e-14, dtype=float32), DeviceArray(-1.9205119e-26, dtype=float32), DeviceArray(-1.1226742e-09, dtype=float32), DeviceArray(4.1917985e-09, dtype=float32), DeviceArray(1.6276375e-17, dtype=float32)]
# 88
# Gradients:  [DeviceArray(-2.2458899e-15, dtype=float32), DeviceArray(5.6232384e-16, dtype=float32), DeviceArray(-1.5496921e-11, dtype=float32), DeviceArray(1.0091814e-09, dtype=float32), DeviceArray(7.247368e-15, dtype=float32), DeviceArray(1.113328e-06, dtype=float32), DeviceArray(1.113328e-06, dtype=float32), DeviceArray(7.2473054e-14, dtype=float32), DeviceArray(-1.9209365e-26, dtype=float32), DeviceArray(-1.1226867e-09, dtype=float32), DeviceArray(4.1918446e-09, dtype=float32), DeviceArray(1.6276557e-17, dtype=float32)]
# 89
# Gradients:  [DeviceArray(-2.2459153e-15, dtype=float32), DeviceArray(5.623302e-16, dtype=float32), DeviceArray(-1.5497095e-11, dtype=float32), DeviceArray(1.009193e-09, dtype=float32), DeviceArray(7.248971e-15, dtype=float32), DeviceArray(1.1133328e-06, dtype=float32), DeviceArray(1.1133328e-06, dtype=float32), DeviceArray(7.248907e-14, dtype=float32), DeviceArray(-1.921361e-26, dtype=float32), DeviceArray(-1.1226993e-09, dtype=float32), DeviceArray(4.191891e-09, dtype=float32), DeviceArray(1.6276746e-17, dtype=float32)]
# 90
# ...
# 472
# Gradients:  [DeviceArray(-2.2390062e-15, dtype=float32), DeviceArray(5.606001e-16, dtype=float32), DeviceArray(-1.5449418e-11, dtype=float32), DeviceArray(1.006088e-09, dtype=float32), DeviceArray(7.832303e-15, dtype=float32), DeviceArray(1.1069925e-06, dtype=float32), DeviceArray(1.1069925e-06, dtype=float32), DeviceArray(7.832235e-14, dtype=float32), DeviceArray(-2.0759753e-26, dtype=float32), DeviceArray(-1.1192453e-09, dtype=float32), DeviceArray(4.178996e-09, dtype=float32), DeviceArray(1.6226665e-17, dtype=float32)]
# 473
# Gradients:  [DeviceArray(-2.2390325e-15, dtype=float32), DeviceArray(5.606066e-16, dtype=float32), DeviceArray(-1.5449596e-11, dtype=float32), DeviceArray(1.0060996e-09, dtype=float32), DeviceArray(7.834098e-15, dtype=float32), DeviceArray(1.1069976e-06, dtype=float32), DeviceArray(1.1069976e-06, dtype=float32), DeviceArray(7.83403e-14, dtype=float32), DeviceArray(-2.076451e-26, dtype=float32), DeviceArray(-1.1192584e-09, dtype=float32), DeviceArray(4.1790424e-09, dtype=float32), DeviceArray(1.6226857e-17, dtype=float32)]
# 474
# Gradients:  [DeviceArray(-2.239056e-15, dtype=float32), DeviceArray(5.606126e-16, dtype=float32), DeviceArray(-1.5449761e-11, dtype=float32), DeviceArray(1.0061102e-09, dtype=float32), DeviceArray(7.835793e-15, dtype=float32), DeviceArray(1.1070017e-06, dtype=float32), DeviceArray(1.1070017e-06, dtype=float32), DeviceArray(7.835726e-14, dtype=float32), DeviceArray(-2.0769007e-26, dtype=float32), DeviceArray(-1.1192701e-09, dtype=float32), DeviceArray(4.1790886e-09, dtype=float32), DeviceArray(1.6227025e-17, dtype=float32)]
# 475
# Gradients:  [DeviceArray(-2.239079e-15, dtype=float32), DeviceArray(5.6061834e-16, dtype=float32), DeviceArray(-1.5449917e-11, dtype=float32), DeviceArray(1.0061205e-09, dtype=float32), DeviceArray(7.83752e-15, dtype=float32), DeviceArray(1.1070056e-06, dtype=float32), DeviceArray(1.1070056e-06, dtype=float32), DeviceArray(7.837453e-14, dtype=float32), DeviceArray(-2.077358e-26, dtype=float32), DeviceArray(-1.1192816e-09, dtype=float32), DeviceArray(4.1791304e-09, dtype=float32), DeviceArray(1.6227193e-17, dtype=float32)]
# 476
# Gradients:  [DeviceArray(-2.2391045e-15, dtype=float32), DeviceArray(5.6062416e-16, dtype=float32), DeviceArray(-1.5450079e-11, dtype=float32), DeviceArray(1.0061311e-09, dtype=float32), DeviceArray(7.839245e-15, dtype=float32), DeviceArray(1.1070091e-06, dtype=float32), DeviceArray(1.1070091e-06, dtype=float32), DeviceArray(7.839178e-14, dtype=float32), DeviceArray(-2.0778156e-26, dtype=float32), DeviceArray(-1.1192932e-09, dtype=float32), DeviceArray(4.1791752e-09, dtype=float32), DeviceArray(1.622736e-17, dtype=float32)]
# 477
# Gradients:  [DeviceArray(-2.2391255e-15, dtype=float32), DeviceArray(5.6062993e-16, dtype=float32), DeviceArray(-1.5450238e-11, dtype=float32), DeviceArray(1.0061413e-09, dtype=float32), DeviceArray(7.84094e-15, dtype=float32), DeviceArray(1.1070132e-06, dtype=float32), DeviceArray(1.1070132e-06, dtype=float32), DeviceArray(7.840872e-14, dtype=float32), DeviceArray(-2.078265e-26, dtype=float32), DeviceArray(-1.1193049e-09, dtype=float32), DeviceArray(4.1792174e-09, dtype=float32), DeviceArray(1.6227528e-17, dtype=float32)]
# 478
# Gradients:  [DeviceArray(-2.2391502e-15, dtype=float32), DeviceArray(5.6063623e-16, dtype=float32), DeviceArray(-1.545041e-11, dtype=float32), DeviceArray(1.0061526e-09, dtype=float32), DeviceArray(7.842674e-15, dtype=float32), DeviceArray(1.1070181e-06, dtype=float32), DeviceArray(1.1070181e-06, dtype=float32), DeviceArray(7.842607e-14, dtype=float32), DeviceArray(-2.0787244e-26, dtype=float32), DeviceArray(-1.1193172e-09, dtype=float32), DeviceArray(4.179264e-09, dtype=float32), DeviceArray(1.6227709e-17, dtype=float32)]
# 479
# Gradients:  [DeviceArray(-2.2391729e-15, dtype=float32), DeviceArray(5.606425e-16, dtype=float32), DeviceArray(-1.545058e-11, dtype=float32), DeviceArray(1.0061637e-09, dtype=float32), DeviceArray(7.844436e-15, dtype=float32), DeviceArray(1.1070224e-06, dtype=float32), DeviceArray(1.1070224e-06, dtype=float32), DeviceArray(7.844369e-14, dtype=float32), DeviceArray(-2.0791913e-26, dtype=float32), DeviceArray(-1.1193295e-09, dtype=float32), DeviceArray(4.1793102e-09, dtype=float32), DeviceArray(1.6227887e-17, dtype=float32)]
# 480
# Gradients:  [DeviceArray(-2.2391958e-15, dtype=float32), DeviceArray(5.6064814e-16, dtype=float32), DeviceArray(-1.5450738e-11, dtype=float32), DeviceArray(1.006174e-09, dtype=float32), DeviceArray(7.846131e-15, dtype=float32), DeviceArray(1.1070263e-06, dtype=float32), DeviceArray(1.1070263e-06, dtype=float32), DeviceArray(7.846064e-14, dtype=float32), DeviceArray(-2.0796407e-26, dtype=float32), DeviceArray(-1.119341e-09, dtype=float32), DeviceArray(4.1793524e-09, dtype=float32), DeviceArray(1.6228053e-17, dtype=float32)]
# 481
# Gradients:  [DeviceArray(-2.239222e-15, dtype=float32), DeviceArray(5.606542e-16, dtype=float32), DeviceArray(-1.5450906e-11, dtype=float32), DeviceArray(1.0061848e-09, dtype=float32), DeviceArray(7.847864e-15, dtype=float32), DeviceArray(1.1070309e-06, dtype=float32), DeviceArray(1.1070309e-06, dtype=float32), DeviceArray(7.847796e-14, dtype=float32), DeviceArray(-2.0800997e-26, dtype=float32), DeviceArray(-1.1193532e-09, dtype=float32), DeviceArray(4.179397e-09, dtype=float32), DeviceArray(1.622823e-17, dtype=float32)]
# 482
# Gradients:  [DeviceArray(-2.2392455e-15, dtype=float32), DeviceArray(5.6065995e-16, dtype=float32), DeviceArray(-1.5451068e-11, dtype=float32), DeviceArray(1.0061953e-09, dtype=float32), DeviceArray(7.8495915e-15, dtype=float32), DeviceArray(1.1070346e-06, dtype=float32), DeviceArray(1.1070346e-06, dtype=float32), DeviceArray(7.849524e-14, dtype=float32), DeviceArray(-2.0805578e-26, dtype=float32), DeviceArray(-1.1193648e-09, dtype=float32), DeviceArray(4.179442e-09, dtype=float32), DeviceArray(1.62284e-17, dtype=float32)]
# 483
# Gradients:  [DeviceArray(-2.2392675e-15, dtype=float32), DeviceArray(5.606661e-16, dtype=float32), DeviceArray(-1.5451236e-11, dtype=float32), DeviceArray(1.0062062e-09, dtype=float32), DeviceArray(7.851293e-15, dtype=float32), DeviceArray(1.1070391e-06, dtype=float32), DeviceArray(1.1070391e-06, dtype=float32), DeviceArray(7.851228e-14, dtype=float32), DeviceArray(-2.0810089e-26, dtype=float32), DeviceArray(-1.1193769e-09, dtype=float32), DeviceArray(4.1794865e-09, dtype=float32), DeviceArray(1.6228574e-17, dtype=float32)]
# 484
# Gradients:  [DeviceArray(-2.2392932e-15, dtype=float32), DeviceArray(5.60672e-16, dtype=float32), DeviceArray(-1.5451397e-11, dtype=float32), DeviceArray(1.0062168e-09, dtype=float32), DeviceArray(7.853054e-15, dtype=float32), DeviceArray(1.1070432e-06, dtype=float32), DeviceArray(1.1070432e-06, dtype=float32), DeviceArray(7.852987e-14, dtype=float32), DeviceArray(-2.0814756e-26, dtype=float32), DeviceArray(-1.1193887e-09, dtype=float32), DeviceArray(4.1795314e-09, dtype=float32), DeviceArray(1.6228746e-17, dtype=float32)]
# 485
# Gradients:  [DeviceArray(-2.239316e-15, dtype=float32), DeviceArray(5.6067816e-16, dtype=float32), DeviceArray(-1.5451569e-11, dtype=float32), DeviceArray(1.0062281e-09, dtype=float32), DeviceArray(7.85479e-15, dtype=float32), DeviceArray(1.1070478e-06, dtype=float32), DeviceArray(1.1070478e-06, dtype=float32), DeviceArray(7.854723e-14, dtype=float32), DeviceArray(-2.0819357e-26, dtype=float32), DeviceArray(-1.1194011e-09, dtype=float32), DeviceArray(4.179577e-09, dtype=float32), DeviceArray(1.6228926e-17, dtype=float32)]
# 486
# Gradients:  [DeviceArray(-2.2393398e-15, dtype=float32), DeviceArray(5.606842e-16, dtype=float32), DeviceArray(-1.5451734e-11, dtype=float32), DeviceArray(1.0062386e-09, dtype=float32), DeviceArray(7.856491e-15, dtype=float32), DeviceArray(1.1070521e-06, dtype=float32), DeviceArray(1.1070521e-06, dtype=float32), DeviceArray(7.856424e-14, dtype=float32), DeviceArray(-2.0823868e-26, dtype=float32), DeviceArray(-1.119413e-09, dtype=float32), DeviceArray(4.1796206e-09, dtype=float32), DeviceArray(1.6229097e-17, dtype=float32)]
# 487
# Gradients:  [DeviceArray(-2.2393654e-15, dtype=float32), DeviceArray(5.6069007e-16, dtype=float32), DeviceArray(-1.5451895e-11, dtype=float32), DeviceArray(1.0062493e-09, dtype=float32), DeviceArray(7.858222e-15, dtype=float32), DeviceArray(1.1070559e-06, dtype=float32), DeviceArray(1.1070559e-06, dtype=float32), DeviceArray(7.858154e-14, dtype=float32), DeviceArray(-2.0828453e-26, dtype=float32), DeviceArray(-1.1194248e-09, dtype=float32), DeviceArray(4.179666e-09, dtype=float32), DeviceArray(1.6229267e-17, dtype=float32)]
# 488
# Gradients:  [DeviceArray(-2.2393895e-15, dtype=float32), DeviceArray(5.6069616e-16, dtype=float32), DeviceArray(-1.5452062e-11, dtype=float32), DeviceArray(1.0062602e-09, dtype=float32), DeviceArray(7.859985e-15, dtype=float32), DeviceArray(1.10706e-06, dtype=float32), DeviceArray(1.10706e-06, dtype=float32), DeviceArray(7.8599176e-14, dtype=float32), DeviceArray(-2.0833126e-26, dtype=float32), DeviceArray(-1.1194369e-09, dtype=float32), DeviceArray(4.1797104e-09, dtype=float32), DeviceArray(1.6229446e-17, dtype=float32)]
# 489
# Gradients:  [DeviceArray(-2.2394134e-15, dtype=float32), DeviceArray(5.607022e-16, dtype=float32), DeviceArray(-1.5452225e-11, dtype=float32), DeviceArray(1.006271e-09, dtype=float32), DeviceArray(7.861688e-15, dtype=float32), DeviceArray(1.1070645e-06, dtype=float32), DeviceArray(1.1070645e-06, dtype=float32), DeviceArray(7.86162e-14, dtype=float32), DeviceArray(-2.0837638e-26, dtype=float32), DeviceArray(-1.1194488e-09, dtype=float32), DeviceArray(4.1797548e-09, dtype=float32), DeviceArray(1.6229618e-17, dtype=float32)]
# 490
# Gradients:  [DeviceArray(-2.239437e-15, dtype=float32), DeviceArray(5.60708e-16, dtype=float32), DeviceArray(-1.5452388e-11, dtype=float32), DeviceArray(1.0062816e-09, dtype=float32), DeviceArray(7.863421e-15, dtype=float32), DeviceArray(1.1070688e-06, dtype=float32), DeviceArray(1.1070688e-06, dtype=float32), DeviceArray(7.8633545e-14, dtype=float32), DeviceArray(-2.0842235e-26, dtype=float32), DeviceArray(-1.1194606e-09, dtype=float32), DeviceArray(4.1797996e-09, dtype=float32), DeviceArray(1.6229785e-17, dtype=float32)]
# 491
# Gradients:  [DeviceArray(-2.2374394e-15, dtype=float32), DeviceArray(5.602086e-16, dtype=float32), DeviceArray(-1.5438628e-11, dtype=float32), DeviceArray(1.0053853e-09, dtype=float32), DeviceArray(7.858067e-15, dtype=float32), DeviceArray(1.1060752e-06, dtype=float32), DeviceArray(1.1060752e-06, dtype=float32), DeviceArray(7.857999e-14, dtype=float32), DeviceArray(-2.0828043e-26, dtype=float32), DeviceArray(-1.1184635e-09, dtype=float32), DeviceArray(4.1760755e-09, dtype=float32), DeviceArray(1.6215337e-17, dtype=float32)]
# 492
# Gradients:  [DeviceArray(-2.237467e-15, dtype=float32), DeviceArray(5.6021446e-16, dtype=float32), DeviceArray(-1.5438787e-11, dtype=float32), DeviceArray(1.0053958e-09, dtype=float32), DeviceArray(7.859798e-15, dtype=float32), DeviceArray(1.1060791e-06, dtype=float32), DeviceArray(1.1060791e-06, dtype=float32), DeviceArray(7.8597305e-14, dtype=float32), DeviceArray(-2.0832633e-26, dtype=float32), DeviceArray(-1.1184753e-09, dtype=float32), DeviceArray(4.1761195e-09, dtype=float32), DeviceArray(1.6215504e-17, dtype=float32)]
# 493
# Gradients:  [DeviceArray(-2.2374905e-15, dtype=float32), DeviceArray(5.602204e-16, dtype=float32), DeviceArray(-1.5438952e-11, dtype=float32), DeviceArray(1.0054064e-09, dtype=float32), DeviceArray(7.86153e-15, dtype=float32), DeviceArray(1.1060831e-06, dtype=float32), DeviceArray(1.1060831e-06, dtype=float32), DeviceArray(7.8614625e-14, dtype=float32), DeviceArray(-2.0837223e-26, dtype=float32), DeviceArray(-1.118487e-09, dtype=float32), DeviceArray(4.176164e-09, dtype=float32), DeviceArray(1.6215673e-17, dtype=float32)]
# 494
# Gradients:  [DeviceArray(-2.237517e-15, dtype=float32), DeviceArray(5.6022643e-16, dtype=float32), DeviceArray(-1.543912e-11, dtype=float32), DeviceArray(1.0054173e-09, dtype=float32), DeviceArray(7.863264e-15, dtype=float32), DeviceArray(1.1060873e-06, dtype=float32), DeviceArray(1.1060873e-06, dtype=float32), DeviceArray(7.863197e-14, dtype=float32), DeviceArray(-2.0841816e-26, dtype=float32), DeviceArray(-1.1184993e-09, dtype=float32), DeviceArray(4.176209e-09, dtype=float32), DeviceArray(1.621585e-17, dtype=float32)]
# 495
# Gradients:  [DeviceArray(-2.2375362e-15, dtype=float32), DeviceArray(5.6023225e-16, dtype=float32), DeviceArray(-1.5439282e-11, dtype=float32), DeviceArray(1.0054279e-09, dtype=float32), DeviceArray(7.864968e-15, dtype=float32), DeviceArray(1.1060918e-06, dtype=float32), DeviceArray(1.1060918e-06, dtype=float32), DeviceArray(7.8648995e-14, dtype=float32), DeviceArray(-2.084633e-26, dtype=float32), DeviceArray(-1.118511e-09, dtype=float32), DeviceArray(4.1762536e-09, dtype=float32), DeviceArray(1.621602e-17, dtype=float32)]
# 496
# Gradients:  [DeviceArray(-2.2375618e-15, dtype=float32), DeviceArray(5.6023834e-16, dtype=float32), DeviceArray(-1.5439447e-11, dtype=float32), DeviceArray(1.0054386e-09, dtype=float32), DeviceArray(7.8667025e-15, dtype=float32), DeviceArray(1.106096e-06, dtype=float32), DeviceArray(1.106096e-06, dtype=float32), DeviceArray(7.866634e-14, dtype=float32), DeviceArray(-2.0850928e-26, dtype=float32), DeviceArray(-1.1185229e-09, dtype=float32), DeviceArray(4.176297e-09, dtype=float32), DeviceArray(1.6216193e-17, dtype=float32)]
# 497
# Gradients:  [DeviceArray(-2.2375853e-15, dtype=float32), DeviceArray(5.6024474e-16, dtype=float32), DeviceArray(-1.543962e-11, dtype=float32), DeviceArray(1.0054501e-09, dtype=float32), DeviceArray(7.868472e-15, dtype=float32), DeviceArray(1.1061006e-06, dtype=float32), DeviceArray(1.1061006e-06, dtype=float32), DeviceArray(7.8684035e-14, dtype=float32), DeviceArray(-2.085562e-26, dtype=float32), DeviceArray(-1.1185357e-09, dtype=float32), DeviceArray(4.176345e-09, dtype=float32), DeviceArray(1.621638e-17, dtype=float32)]
# 498
# Gradients:  [DeviceArray(-2.2376116e-15, dtype=float32), DeviceArray(5.602502e-16, dtype=float32), DeviceArray(-1.5439773e-11, dtype=float32), DeviceArray(1.00546e-09, dtype=float32), DeviceArray(7.870172e-15, dtype=float32), DeviceArray(1.1061042e-06, dtype=float32), DeviceArray(1.1061042e-06, dtype=float32), DeviceArray(7.8701036e-14, dtype=float32), DeviceArray(-2.0860128e-26, dtype=float32), DeviceArray(-1.1185467e-09, dtype=float32), DeviceArray(4.1763877e-09, dtype=float32), DeviceArray(1.621654e-17, dtype=float32)]
# 499
# Gradients:  [DeviceArray(-2.2376347e-15, dtype=float32), DeviceArray(5.602566e-16, dtype=float32), DeviceArray(-1.5439946e-11, dtype=float32), DeviceArray(1.0054712e-09, dtype=float32), DeviceArray(7.871911e-15, dtype=float32), DeviceArray(1.1061089e-06, dtype=float32), DeviceArray(1.1061089e-06, dtype=float32), DeviceArray(7.871842e-14, dtype=float32), DeviceArray(-2.0864733e-26, dtype=float32), DeviceArray(-1.1185592e-09, dtype=float32), DeviceArray(4.176433e-09, dtype=float32), DeviceArray(1.621672e-17, dtype=float32)]
# [DeviceArray(174.28572, dtype=float32), DeviceArray(461.58102, dtype=float32), DeviceArray(177.36673, dtype=float32), DeviceArray(0.8993937, dtype=float32), DeviceArray(-3.7460065e-12, dtype=float32), DeviceArray(-0.00055539, dtype=float32), DeviceArray(-0.00055539, dtype=float32), DeviceArray(-3.745976e-11, dtype=float32), DeviceArray(88., dtype=float32), DeviceArray(13., dtype=float32), DeviceArray(0.80668736, dtype=float32), DeviceArray(1092.6569, dtype=float32)]
#
#
# Surrogate Treatment:
#  [DeviceArray(174.28572, dtype=float32), DeviceArray(461.58102, dtype=float32), DeviceArray(177.36673, dtype=float32), DeviceArray(0.8993937, dtype=float32), DeviceArray(-3.7460065e-12, dtype=float32), DeviceArray(-0.00055539, dtype=float32), DeviceArray(-0.00055539, dtype=float32), DeviceArray(-3.745976e-11, dtype=float32), DeviceArray(88., dtype=float32), DeviceArray(13., dtype=float32), DeviceArray(0.80668736, dtype=float32), DeviceArray(1092.6569, dtype=float32)]
